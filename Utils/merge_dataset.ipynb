# %% [markdown]
# ## Merge 2 dataset

# %%
import os
import glob

# %% [markdown]
# ## Đọc dataset Student-Behavior

# %% [markdown]
# ## SCB

# %% [markdown]
# ## Visualize số ảnh số lớp

# %% [markdown]
# ### Bouding box

# %% [markdown]
# ## Student

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
# Định nghĩa tên lớp theo chỉ số (theo file YAML: nc:3, names: ['hand-raising','read','write'])
class_names = {0: 'drinking', 1: 'raising_hand', 2: 'sleeping', 3: 'using_computer', 4: 'using_phone', 5: 'writing'}

# Đường dẫn tới folder ảnh và label cho train và val
train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/images"
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels"
val_images_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/images"
val_labels_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels"
test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/images"
test_labels_dir ="/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels"

# Các định dạng ảnh hợp lệ
valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]


def find_image_file(base_name, images_dir):
    """
    Với base_name (tên file không có phần mở rộng) và thư mục chứa ảnh,
    tìm file ảnh có đuôi hợp lệ và trả về đường dẫn, nếu không tìm thấy trả về None.
    """
    for ext in valid_extensions:
        image_path = os.path.join(images_dir, base_name + ext)
        if os.path.exists(image_path):
            return image_path
    return None

def parse_label_file(label_file):
    """
    Đọc file label (YOLO format) và trả về danh sách các tuple:
    (cls, x_center, y_center, bbox_width, bbox_height)
    """
    boxes = []
    with open(label_file, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(parts[0])
            x_center, y_center, bw, bh = map(float, parts[1:5])
            boxes.append((cls, x_center, y_center, bw, bh))
    return boxes

def draw_target_boxes(image_path, label_file, target_class):
    """
    Vẽ bounding boxes của target_class lên ảnh.
    Chỉ vẽ các box có lớp (target_class).
    """
    image = cv2.imread(image_path)
    if image is None:
        return None
    h, w, _ = image.shape
    boxes = parse_label_file(label_file)
    for box in boxes:
        cls, x_center, y_center, bw, bh = box
        if cls != target_class:
            continue
        # Chuyển tọa độ từ normalized sang pixel
        x_center_pixel = x_center * w
        y_center_pixel = y_center * h
        bw_pixel = bw * w
        bh_pixel = bh * h
        x_min = int(x_center_pixel - bw_pixel / 2)
        y_min = int(y_center_pixel - bh_pixel / 2)
        x_max = int(x_center_pixel + bw_pixel / 2)
        y_max = int(y_center_pixel + bh_pixel / 2)
        # Vẽ box và ghi tên lớp
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        cv2.putText(image, class_names[cls], (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

def collect_images_by_class(labels_dir, images_dir):
    """
    Duyệt qua tất cả các file label trong folder labels_dir và xây dựng dictionary:
        { class: set( (image_path, label_path) ) }
    Dùng set để tránh trùng lặp nếu ảnh chứa nhiều box của cùng một lớp.
    """
    images_by_class = {0: set(), 1: set(), 2: set()}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        base_name = os.path.splitext(label_filename)[0]
        image_file = find_image_file(base_name, images_dir)
        if image_file is None:
            continue
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in images_by_class:
                images_by_class[cls].add((image_file, label_file))
    # Chuyển set thành list để dễ thao tác
    for cls in images_by_class:
        images_by_class[cls] = list(images_by_class[cls])
    return images_by_class

def visualize_samples(dataset_type, images_dir, labels_dir):
    """
    Với dataset (train hoặc val), hiển thị 5 mẫu ảnh cho mỗi lớp.
    Chỉ vẽ bounding boxes của lớp đó.
    """
    images_by_class = collect_images_by_class(labels_dir, images_dir)
    for cls in class_names:
        samples = images_by_class.get(cls, [])
        if len(samples) == 0:
            print(f"Không có ảnh cho lớp {class_names[cls]}")
            continue
        # Chọn ngẫu nhiên tối đa 5 mẫu
        selected_samples = random.sample(samples, min(5, len(samples)))
        plt.figure(figsize=(15, 5))
        for i, (img_path, lbl_path) in enumerate(selected_samples):
            img_with_boxes = draw_target_boxes(img_path, lbl_path, cls)
            if img_with_boxes is None:
                continue
            # Chuyển ảnh từ BGR (OpenCV) sang RGB (matplotlib)
            img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
            plt.subplot(1, 5, i+1)
            plt.imshow(img_rgb)
            plt.title(f"{class_names[cls]}")
            plt.axis('off')
        plt.suptitle(f"{dataset_type.upper()} - Lớp {class_names[cls]}")
        plt.show()

def count_labels(labels_dir):
    """
    Đếm tổng số bounding boxes theo lớp trong folder labels.
    """
    counts = {0: 0, 1: 0, 2: 0}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in counts:
                counts[cls] += 1
    return counts

def visualize_label_counts(train_labels_dir, val_labels_dir):
    """
    Visualize số lượng bounding boxes theo lớp cho cả file train và val.
    """
    train_counts = count_labels(train_labels_dir)
    val_counts = count_labels(val_labels_dir)
    
    classes = list(class_names.keys())  # [0, 1, 2]
    class_labels = [class_names[k] for k in classes]
    train_values = [train_counts[k] for k in classes]
    val_values = [val_counts[k] for k in classes]

    x = range(len(classes))
    width = 0.35  # chiều rộng của mỗi cột

    plt.figure(figsize=(10, 6))
    plt.bar(x, train_values, width=width, label='Train', color='skyblue')
    plt.bar([i + width for i in x], val_values, width=width, label='Validation', color='salmon')
    plt.xticks([i + width/2 for i in x], class_labels)
    plt.xlabel("Lớp")
    plt.ylabel("Số lượng bounding boxes")
    plt.title("Số lượng bounding boxes theo lớp trong Train và Validation")
    plt.legend()
    plt.show()

# Visualize samples cho tập train
print("Visualize samples từ tập train:")
visualize_samples("train", train_images_dir, train_labels_dir)

# Visualize samples cho tập val
print("Visualize samples từ tập val:")
visualize_samples("val", val_images_dir, val_labels_dir)

# Visualize số lượng bounding boxes theo lớp cho cả train và val
print("Visualize số lượng bounding boxes theo lớp cho cả train và validation:")
visualize_label_counts(train_labels_dir, val_labels_dir)
# Out:
# Visualize samples từ tập train:
# Không có ảnh cho lớp using_computer
# Không có ảnh cho lớp using_phone
# Không có ảnh cho lớp writing
# Visualize samples từ tập val:
# Không có ảnh cho lớp using_computer
# Không có ảnh cho lớp using_phone
# Không có ảnh cho lớp writing
# Visualize số lượng bounding boxes theo lớp cho cả train và validation:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 178
#     176 # Visualize số lượng bounding boxes theo lớp cho cả train và val
#     177 print("Visualize số lượng bounding boxes theo lớp cho cả train và validation:")
# --> 178 visualize_label_counts(train_labels_dir, val_labels_dir)
#
# Cell In[7], line 152, in visualize_label_counts(train_labels_dir, val_labels_dir)
#     150 classes = list(class_names.keys())  # [0, 1, 2]
#     151 class_labels = [class_names[k] for k in classes]
# --> 152 train_values = [train_counts[k] for k in classes]
#     153 val_values = [val_counts[k] for k in classes]
#     155 x = range(len(classes))
#
# KeyError: 3

# %% [markdown]
# ## Visualize student

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# Định nghĩa các lớp
class_names = {0: 'drinking', 1: 'raising_hand', 2: 'sleeping', 
               3: 'using_computer', 4: 'using_phone', 5: 'writing'}

# Đường dẫn đến các thư mục labels
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels"
val_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels"
test_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels"

def count_classes(labels_dir):
    """Đếm số lượng objects cho từng class trong thư mục labels"""
    counts = {cls: 0 for cls in class_names.keys()}
    
    for filename in os.listdir(labels_dir):
        if filename.endswith('.txt'):
            with open(os.path.join(labels_dir, filename), 'r') as f:
                lines = f.readlines()
                for line in lines:
                    if line.strip():
                        cls_id = int(line.strip().split()[0])
                        if cls_id in counts:
                            counts[cls_id] += 1
    return counts

# Lấy số lượng objects cho từng tập
train_counts = count_classes(train_labels_dir)
val_counts = count_classes(val_labels_dir)
test_counts = count_classes(test_labels_dir)

# Chuẩn bị dữ liệu để visualize
classes = sorted(class_names.keys())
class_labels = [class_names[cls] for cls in classes]
train_values = [train_counts[cls] for cls in classes]
val_values = [val_counts[cls] for cls in classes]
test_values = [test_counts[cls] for cls in classes]

x = np.arange(len(class_labels))  # Vị trí các nhãn
width = 0.25  # Độ rộng của các cột

# Vẽ biểu đồ
fig, ax = plt.subplots(figsize=(14, 8))
rects1 = ax.bar(x - width, train_values, width, label='Train')
rects2 = ax.bar(x, val_values, width, label='Validation')
rects3 = ax.bar(x + width, test_values, width, label='Test')

# Thêm các thành phần cho biểu đồ
ax.set_ylabel('Số lượng instances')
ax.set_title('Phân bố số lượng instances theo lớp và tập dữ liệu')
ax.set_xticks(x)
ax.set_xticklabels(class_labels, rotation=45, ha='right')
ax.legend()

# Hiển thị số trên mỗi cột
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width()/2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## SCB

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# Định nghĩa tên lớp theo chỉ số (theo file YAML: nc:3, names: ['hand-raising','read','write'])
class_names = {0: 'hand-raising', 1: 'read', 2: 'write'}

# Đường dẫn tới folder ảnh và label cho train và val
train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train"
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/train"
val_images_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val"
val_labels_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/val"

# Các định dạng ảnh hợp lệ
valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

def find_image_file(base_name, images_dir):
    """
    Với base_name (tên file không có phần mở rộng) và thư mục chứa ảnh,
    tìm file ảnh có đuôi hợp lệ và trả về đường dẫn, nếu không tìm thấy trả về None.
    """
    for ext in valid_extensions:
        image_path = os.path.join(images_dir, base_name + ext)
        if os.path.exists(image_path):
            return image_path
    return None

def parse_label_file(label_file):
    """
    Đọc file label (YOLO format) và trả về danh sách các tuple:
    (cls, x_center, y_center, bbox_width, bbox_height)
    """
    boxes = []
    with open(label_file, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(parts[0])
            x_center, y_center, bw, bh = map(float, parts[1:5])
            boxes.append((cls, x_center, y_center, bw, bh))
    return boxes

def draw_target_boxes(image_path, label_file, target_class):
    """
    Vẽ bounding boxes của target_class lên ảnh.
    Chỉ vẽ các box có lớp (target_class).
    """
    image = cv2.imread(image_path)
    if image is None:
        return None
    h, w, _ = image.shape
    boxes = parse_label_file(label_file)
    for box in boxes:
        cls, x_center, y_center, bw, bh = box
        if cls != target_class:
            continue
        # Chuyển tọa độ từ normalized sang pixel
        x_center_pixel = x_center * w
        y_center_pixel = y_center * h
        bw_pixel = bw * w
        bh_pixel = bh * h
        x_min = int(x_center_pixel - bw_pixel / 2)
        y_min = int(y_center_pixel - bh_pixel / 2)
        x_max = int(x_center_pixel + bw_pixel / 2)
        y_max = int(y_center_pixel + bh_pixel / 2)
        # Vẽ box và ghi tên lớp
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        cv2.putText(image, class_names[cls], (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

def collect_images_by_class(labels_dir, images_dir):
    """
    Duyệt qua tất cả các file label trong folder labels_dir và xây dựng dictionary:
        { class: set( (image_path, label_path) ) }
    Dùng set để tránh trùng lặp nếu ảnh chứa nhiều box của cùng một lớp.
    """
    images_by_class = {0: set(), 1: set(), 2: set()}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        base_name = os.path.splitext(label_filename)[0]
        image_file = find_image_file(base_name, images_dir)
        if image_file is None:
            continue
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in images_by_class:
                images_by_class[cls].add((image_file, label_file))
    # Chuyển set thành list để dễ thao tác
    for cls in images_by_class:
        images_by_class[cls] = list(images_by_class[cls])
    return images_by_class

def visualize_samples(dataset_type, images_dir, labels_dir):
    """
    Với dataset (train hoặc val), hiển thị 5 mẫu ảnh cho mỗi lớp.
    Chỉ vẽ bounding boxes của lớp đó.
    """
    images_by_class = collect_images_by_class(labels_dir, images_dir)
    for cls in class_names:
        samples = images_by_class.get(cls, [])
        if len(samples) == 0:
            print(f"Không có ảnh cho lớp {class_names[cls]}")
            continue
        # Chọn ngẫu nhiên tối đa 5 mẫu
        selected_samples = random.sample(samples, min(5, len(samples)))
        plt.figure(figsize=(15, 5))
        for i, (img_path, lbl_path) in enumerate(selected_samples):
            img_with_boxes = draw_target_boxes(img_path, lbl_path, cls)
            if img_with_boxes is None:
                continue
            # Chuyển ảnh từ BGR (OpenCV) sang RGB (matplotlib)
            img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
            plt.subplot(1, 5, i+1)
            plt.imshow(img_rgb)
            plt.title(f"{class_names[cls]}")
            plt.axis('off')
        plt.suptitle(f"{dataset_type.upper()} - Lớp {class_names[cls]}")
        plt.show()

def count_labels(labels_dir):
    """
    Đếm tổng số bounding boxes theo lớp trong folder labels.
    """
    counts = {0: 0, 1: 0, 2: 0}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in counts:
                counts[cls] += 1
    return counts

def visualize_label_counts(train_labels_dir, val_labels_dir):
    """
    Visualize số lượng bounding boxes theo lớp cho cả file train và val.
    """
    train_counts = count_labels(train_labels_dir)
    val_counts = count_labels(val_labels_dir)
    
    classes = list(class_names.keys())  # [0, 1, 2]
    class_labels = [class_names[k] for k in classes]
    train_values = [train_counts[k] for k in classes]
    val_values = [val_counts[k] for k in classes]

    x = range(len(classes))
    width = 0.35  # chiều rộng của mỗi cột

    plt.figure(figsize=(10, 6))
    plt.bar(x, train_values, width=width, label='Train', color='skyblue')
    plt.bar([i + width for i in x], val_values, width=width, label='Validation', color='salmon')
    plt.xticks([i + width/2 for i in x], class_labels)
    plt.xlabel("Lớp")
    plt.ylabel("Số lượng bounding boxes")
    plt.title("Số lượng bounding boxes theo lớp trong Train và Validation")
    plt.legend()
    plt.show()

# Visualize samples cho tập train
print("Visualize samples từ tập train:")
visualize_samples("train", train_images_dir, train_labels_dir)

# Visualize samples cho tập val
print("Visualize samples từ tập val:")
visualize_samples("val", val_images_dir, val_labels_dir)

# Visualize số lượng bounding boxes theo lớp cho cả train và val
print("Visualize số lượng bounding boxes theo lớp cho cả train và validation:")
visualize_label_counts(train_labels_dir, val_labels_dir)
# Out:
# Visualize samples từ tập train:
# Visualize samples từ tập val:
# Visualize số lượng bounding boxes theo lớp cho cả train và validation:

# %% [markdown]
# ### Di chuyển 10% train và 5% valid sang test

# %%
import os
import random
import shutil

# Đường dẫn tới folder images và labels của train, valid và test
train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train"
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/train"
val_images_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val"
val_labels_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/val"


# Folder đích cho tập test
test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/test"
test_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/test"

# Tạo folder test nếu chưa tồn tại
os.makedirs(test_images_dir, exist_ok=True)
os.makedirs(test_labels_dir, exist_ok=True)

# Các định dạng ảnh hợp lệ
valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

def move_sample(src_images_dir, src_labels_dir, dest_images_dir, dest_labels_dir, percent):
    """
    Di chuyển ngẫu nhiên một tỉ lệ percent (%) ảnh từ src_images_dir sang dest_images_dir,
    đồng thời di chuyển file label tương ứng từ src_labels_dir sang dest_labels_dir nếu có.
    """
    # Lấy danh sách file ảnh có định dạng hợp lệ trong src_images_dir
    all_images = [f for f in os.listdir(src_images_dir) if os.path.splitext(f)[1].lower() in valid_extensions]
    
    # Xác định số lượng ảnh cần di chuyển
    sample_count = int(len(all_images) * percent / 100)
    print(f"Từ {src_images_dir}: {len(all_images)} ảnh, sẽ di chuyển {sample_count} ảnh ({percent}%).")
    
    # Lấy mẫu ngẫu nhiên
    sample_images = random.sample(all_images, sample_count)
    
    for image_file in sample_images:
        # Di chuyển file ảnh
        src_image_path = os.path.join(src_images_dir, image_file)
        dest_image_path = os.path.join(dest_images_dir, image_file)
        shutil.move(src_image_path, dest_image_path)
        
        # Di chuyển file label tương ứng (nếu có)
        base_name = os.path.splitext(image_file)[0]
        label_file = base_name + ".txt"
        src_label_path = os.path.join(src_labels_dir, label_file)
        if os.path.exists(src_label_path):
            dest_label_path = os.path.join(dest_labels_dir, label_file)
            shutil.move(src_label_path, dest_label_path)

# Di chuyển 10% từ train sang test
move_sample(train_images_dir, train_labels_dir, test_images_dir, test_labels_dir, 10)

# Di chuyển 5% từ valid sang test
move_sample(val_images_dir, val_labels_dir, test_images_dir, test_labels_dir, 5)
# Out:
# Từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train: 5193 ảnh, sẽ di chuyển 519 ảnh (10%).
# Từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val: 1671 ảnh, sẽ di chuyển 83 ảnh (5%).

# %% [markdown]
# ### THống kê train, valid, test

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# Định nghĩa tên lớp theo chỉ số (theo file YAML: nc:3, names: ['hand-raising','read','write'])
class_names = {0: 'hand-raising', 1: 'read', 2: 'write'}

# Đường dẫn tới folder ảnh và label cho train, val và test
# Đường dẫn tới folder images và labels của train, valid và test
train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train"
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/train"
val_images_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val"
val_labels_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/val"


# Folder đích cho tập test
test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/test"
test_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/test"

# Các định dạng ảnh hợp lệ
valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

def find_image_file(base_name, images_dir):
    """
    Với base_name (tên file không có phần mở rộng) và thư mục chứa ảnh,
    tìm file ảnh có đuôi hợp lệ và trả về đường dẫn, nếu không tìm thấy trả về None.
    """
    for ext in valid_extensions:
        image_path = os.path.join(images_dir, base_name + ext)
        if os.path.exists(image_path):
            return image_path
    return None

def parse_label_file(label_file):
    """
    Đọc file label (YOLO format) và trả về danh sách các tuple:
    (cls, x_center, y_center, bbox_width, bbox_height)
    """
    boxes = []
    with open(label_file, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(parts[0])
            x_center, y_center, bw, bh = map(float, parts[1:5])
            boxes.append((cls, x_center, y_center, bw, bh))
    return boxes

def draw_target_boxes(image_path, label_file, target_class):
    """
    Vẽ bounding boxes của target_class lên ảnh.
    Chỉ vẽ các box có lớp (target_class).
    """
    image = cv2.imread(image_path)
    if image is None:
        return None
    h, w, _ = image.shape
    boxes = parse_label_file(label_file)
    for box in boxes:
        cls, x_center, y_center, bw, bh = box
        if cls != target_class:
            continue
        # Chuyển tọa độ từ normalized sang pixel
        x_center_pixel = x_center * w
        y_center_pixel = y_center * h
        bw_pixel = bw * w
        bh_pixel = bh * h
        x_min = int(x_center_pixel - bw_pixel / 2)
        y_min = int(y_center_pixel - bh_pixel / 2)
        x_max = int(x_center_pixel + bw_pixel / 2)
        y_max = int(y_center_pixel + bh_pixel / 2)
        # Vẽ box và ghi tên lớp
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        cv2.putText(image, class_names[cls], (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

def collect_images_by_class(labels_dir, images_dir):
    """
    Duyệt qua tất cả các file label trong folder labels_dir và xây dựng dictionary:
        { class: set( (image_path, label_path) ) }
    Dùng set để tránh trùng lặp nếu ảnh chứa nhiều box của cùng một lớp.
    """
    images_by_class = {0: set(), 1: set(), 2: set()}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        base_name = os.path.splitext(label_filename)[0]
        image_file = find_image_file(base_name, images_dir)
        if image_file is None:
            continue
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in images_by_class:
                images_by_class[cls].add((image_file, label_file))
    # Chuyển set thành list để dễ thao tác
    for cls in images_by_class:
        images_by_class[cls] = list(images_by_class[cls])
    return images_by_class

def visualize_samples(dataset_type, images_dir, labels_dir):
    """
    Với dataset (train, val hoặc test), hiển thị 5 mẫu ảnh cho mỗi lớp.
    Chỉ vẽ bounding boxes của lớp đó.
    """
    images_by_class = collect_images_by_class(labels_dir, images_dir)
    for cls in class_names:
        samples = images_by_class.get(cls, [])
        if len(samples) == 0:
            print(f"Không có ảnh cho lớp {class_names[cls]} ở dataset {dataset_type}")
            continue
        # Chọn ngẫu nhiên tối đa 5 mẫu
        selected_samples = random.sample(samples, min(5, len(samples)))
        plt.figure(figsize=(15, 5))
        for i, (img_path, lbl_path) in enumerate(selected_samples):
            img_with_boxes = draw_target_boxes(img_path, lbl_path, cls)
            if img_with_boxes is None:
                continue
            # Chuyển ảnh từ BGR (OpenCV) sang RGB (matplotlib)
            img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
            plt.subplot(1, 5, i+1)
            plt.imshow(img_rgb)
            plt.title(f"{class_names[cls]}")
            plt.axis('off')
        plt.suptitle(f"{dataset_type.upper()} - Lớp {class_names[cls]}")
        plt.show()

def count_labels(labels_dir):
    """
    Đếm tổng số bounding boxes theo lớp trong folder labels.
    """
    counts = {0: 0, 1: 0, 2: 0}
    for label_filename in os.listdir(labels_dir):
        if not label_filename.endswith(".txt"):
            continue
        label_file = os.path.join(labels_dir, label_filename)
        boxes = parse_label_file(label_file)
        for box in boxes:
            cls = box[0]
            if cls in counts:
                counts[cls] += 1
    return counts

def visualize_label_counts(train_labels_dir, val_labels_dir):
    """
    Visualize số lượng bounding boxes theo lớp cho cả train và validation.
    """
    train_counts = count_labels(train_labels_dir)
    val_counts = count_labels(val_labels_dir)
    
    classes = list(class_names.keys())  # [0, 1, 2]
    class_labels = [class_names[k] for k in classes]
    train_values = [train_counts[k] for k in classes]
    val_values = [val_counts[k] for k in classes]

    x = range(len(classes))
    width = 0.35  # chiều rộng của mỗi cột

    plt.figure(figsize=(10, 6))
    plt.bar(x, train_values, width=width, label='Train', color='skyblue')
    plt.bar([i + width for i in x], val_values, width=width, label='Validation', color='salmon')
    plt.xticks([i + width/2 for i in x], class_labels)
    plt.xlabel("Lớp")
    plt.ylabel("Số lượng bounding boxes")
    plt.title("Số lượng bounding boxes theo lớp trong Train và Validation")
    plt.legend()
    plt.show()

def visualize_all_label_counts(train_labels_dir, val_labels_dir, test_labels_dir):
    """
    Visualize số lượng bounding boxes theo lớp cho cả Train, Validation và Test.
    """
    train_counts = count_labels(train_labels_dir)
    val_counts = count_labels(val_labels_dir)
    test_counts = count_labels(test_labels_dir)
    
    classes = list(class_names.keys())
    class_labels = [class_names[k] for k in classes]
    train_values = [train_counts[k] for k in classes]
    val_values = [val_counts[k] for k in classes]
    test_values = [test_counts[k] for k in classes]

    x = range(len(classes))
    width = 0.25  # giảm chiều rộng vì có 3 nhóm cột

    plt.figure(figsize=(10, 6))
    plt.bar([i - width for i in x], train_values, width=width, label='Train', color='skyblue')
    plt.bar(x, val_values, width=width, label='Validation', color='salmon')
    plt.bar([i + width for i in x], test_values, width=width, label='Test', color='lightgreen')
    plt.xticks(x, class_labels)
    plt.xlabel("Lớp")
    plt.ylabel("Số lượng bounding boxes")
    plt.title("Số lượng bounding boxes theo lớp trong Train, Validation và Test")
    plt.legend()
    plt.show()

# Visualize samples cho từng dataset
print("Visualize samples từ tập train:")
visualize_samples("train", train_images_dir, train_labels_dir)

print("Visualize samples từ tập val:")
visualize_samples("val", val_images_dir, val_labels_dir)

print("Visualize samples từ tập test:")
visualize_samples("test", test_images_dir, test_labels_dir)

# Visualize số lượng bounding boxes theo lớp cho Train và Validation
print("Visualize số lượng bounding boxes theo lớp cho Train và Validation:")
visualize_label_counts(train_labels_dir, val_labels_dir)

# Visualize số lượng bounding boxes theo lớp cho Train, Validation và Test
print("Visualize số lượng bounding boxes theo lớp cho Train, Validation và Test:")
visualize_all_label_counts(train_labels_dir, val_labels_dir, test_labels_dir)
# Out:
# Visualize samples từ tập train:
# Visualize samples từ tập val:
# Visualize samples từ tập test:
# Visualize số lượng bounding boxes theo lớp cho Train và Validation:
# Visualize số lượng bounding boxes theo lớp cho Train, Validation và Test:

# %% [markdown]
# **Bây giờ tôi muốn map. giữa dataset Student và dataset**
# - SCB: Ở Student có ['drinking', 'raising_hand', 'sleeping', 'using_computer', 'using_phone', 'writing'] Ở SCB
# - có  ['hand-raising','read','write']. Map giữa hand-raising vào raising_hand, write vào writing.
# - Ý muốn của tôi là merge SCB vào Student

# %%
import os
import shutil

# Mapping của từng dataset
student_mapping = {
    0: 'drinking',
    1: 'raising_hand',
    2: 'sleeping',
    3: 'using_computer',
    4: 'using_phone',
    5: 'writing'
}

scb_mapping = {
    0: 'hand-raising',  # sẽ map sang 'raising_hand'
    1: 'read',
    2: 'write'          # sẽ map sang 'writing'
}

# Unified mapping: sử dụng định nghĩa của Student, bổ sung lớp 'read'
unified_mapping = {
    'drinking': 0,
    'raising_hand': 1,
    'sleeping': 2,
    'using_computer': 3,
    'using_phone': 4,
    'writing': 5,
    'read': 6
}

def update_scb_annotation_line(line):
    """
    Chuyển đổi một dòng annotation của SCB sang unified mapping.
    Dòng annotation có định dạng: "cls x_center y_center width height"
    """
    parts = line.strip().split()
    if len(parts) < 5:
        return line  # nếu dòng không hợp lệ
    orig_cls = int(parts[0])
    
    # Lấy tên nhãn theo SCB
    class_name = scb_mapping.get(orig_cls)
    if class_name is None:
        return line
    
    # Map tên nhãn:
    # hand-raising -> raising_hand, write -> writing (read giữ nguyên)
    if class_name == 'hand-raising':
        class_name = 'raising_hand'
    elif class_name == 'write':
        class_name = 'writing'
    
    # Lấy số nhãn mới theo unified_mapping
    new_cls = unified_mapping.get(class_name)
    parts[0] = str(new_cls)
    return " ".join(parts)

def process_scb_annotations(scb_labels_dir, output_labels_dir):
    """
    Chuyển đổi toàn bộ file annotation của SCB và lưu vào output_labels_dir.
    """
    if not os.path.exists(output_labels_dir):
        os.makedirs(output_labels_dir)
    for filename in os.listdir(scb_labels_dir):
        if not filename.endswith(".txt"):
            continue
        input_path = os.path.join(scb_labels_dir, filename)
        output_path = os.path.join(output_labels_dir, filename)
        with open(input_path, 'r') as f:
            lines = f.readlines()
        updated_lines = [update_scb_annotation_line(line) for line in lines]
        with open(output_path, 'w') as f:
            f.write("\n".join(updated_lines))
        print(f"Processed annotation: {filename}")

def merge_scb_images(scb_images_dir, dest_images_dir):
    """
    Copy toàn bộ ảnh từ SCB sang dest_images_dir.
    """
    if not os.path.exists(dest_images_dir):
        os.makedirs(dest_images_dir)
    valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]
    for filename in os.listdir(scb_images_dir):
        ext = os.path.splitext(filename)[1].lower()
        if ext in valid_extensions:
            src_path = os.path.join(scb_images_dir, filename)
            dest_path = os.path.join(dest_images_dir, filename)
            shutil.copy(src_path, dest_path)
            print(f"Copied image: {filename}")

# Ví dụ đường dẫn:
# Dataset Student (đã có sẵn)
# Đường dẫn tới folder ảnh và label cho train và val
train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/images"
train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels"
val_images_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/images"
val_labels_dir   = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels"
test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/images"
test_labels_dir ="/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels"

# Dataset SCB ban đầu
train_scb_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/train"
train_scb_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/train"
valid_scb_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/valid"
valid_scb_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/valid"
test_scb_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/test"
test_scb_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/test"

# Folder output cho dataset merged (Student đã merge SCB)
merged_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/merged_dataset/labels"
merged_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/merged_dataset/images"

# Bước 1: Copy file annotation của Student sang merged (nếu cần)
# Nếu Student đã sử dụng unified mapping thì có thể giữ nguyên.
if not os.path.exists(merged_labels_dir):
    os.makedirs(merged_labels_dir)
for filename in os.listdir(student_labels_dir):
    if filename.endswith(".txt"):
        shutil.copy(os.path.join(student_labels_dir, filename),
                    os.path.join(merged_labels_dir, filename))

# Bước 2: Process annotation của SCB và copy vào merged
process_scb_annotations(scb_labels_dir, merged_labels_dir)

# Bước 3: Copy ảnh của Student sang merged (nếu chưa có)
if not os.path.exists(merged_images_dir):
    os.makedirs(merged_images_dir)
for filename in os.listdir(student_images_dir):
    ext = os.path.splitext(filename)[1].lower()
    if ext in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
        shutil.copy(os.path.join(student_images_dir, filename),
                    os.path.join(merged_images_dir, filename))

# Bước 4: Copy ảnh của SCB sang merged
merge_scb_images(scb_images_dir, merged_images_dir)

print("Merge dataset thành công!")
# Out:
# Merge dataset thành công!

# %% [markdown]
# ### Visulize sau khi merge

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
from collections import Counter


merged_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/merged_dataset_student_scb/labels"
merged_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/merged_dataset_student_scb/images"

# Các định dạng ảnh hợp lệ
valid_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

# Unified class mapping (theo định nghĩa của Student, bổ sung read từ SCB)
class_names = {
    0: 'drinking',
    1: 'raising_hand',
    2: 'sleeping',
    3: 'using_computer',
    4: 'using_phone',
    5: 'writing',
    6: 'read'
}

def find_image_file(base_name, images_dir):
    """
    Tìm file ảnh có tên base_name với các định dạng hợp lệ.
    """
    for ext in valid_extensions:
        image_path = os.path.join(images_dir, base_name + ext)
        if os.path.exists(image_path):
            return image_path
    return None

def parse_label_file(label_file):
    """
    Đọc file label (YOLO format) và trả về danh sách các tuple:
    (cls, x_center, y_center, bbox_width, bbox_height)
    """
    boxes = []
    with open(label_file, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls = int(parts[0])
            x_center, y_center, bw, bh = map(float, parts[1:5])
            boxes.append((cls, x_center, y_center, bw, bh))
    return boxes

def draw_bounding_boxes(image, boxes):
    """
    Vẽ tất cả các bounding box lên ảnh dựa trên danh sách boxes.
    Các giá trị trong boxes được giả định là normalized (0-1).
    """
    h, w, _ = image.shape
    for box in boxes:
        cls, x_center, y_center, bw, bh = box
        # Chuyển tọa độ từ normalized sang pixel
        x_center_pixel = x_center * w
        y_center_pixel = y_center * h
        bw_pixel = bw * w
        bh_pixel = bh * h
        x_min = int(x_center_pixel - bw_pixel / 2)
        y_min = int(y_center_pixel - bh_pixel / 2)
        x_max = int(x_center_pixel + bw_pixel / 2)
        y_max = int(y_center_pixel + bh_pixel / 2)
        # Vẽ bounding box
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        # Hiển thị tên lớp
        label_text = class_names.get(cls, str(cls))
        cv2.putText(image, label_text, (x_min, y_min - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

def visualize_samples(images_dir, labels_dir, sample_count=5):
    """
    Chọn ngẫu nhiên một số file label từ dataset, sau đó vẽ bounding box lên ảnh mẫu.
    """
    # Lấy danh sách file label
    label_files = [f for f in os.listdir(labels_dir) if f.endswith(".txt")]
    if not label_files:
        print("Không tìm thấy file label nào.")
        return
    selected_files = random.sample(label_files, min(sample_count, len(label_files)))
    
    plt.figure(figsize=(15, 5))
    for i, label_file in enumerate(selected_files):
        base_name = os.path.splitext(label_file)[0]
        image_path = find_image_file(base_name, images_dir)
        if image_path is None:
            continue
        full_label_path = os.path.join(labels_dir, label_file)
        boxes = parse_label_file(full_label_path)
        img = cv2.imread(image_path)
        if img is None:
            continue
        img_with_boxes = draw_bounding_boxes(img.copy(), boxes)
        # Chuyển từ BGR sang RGB để hiển thị với matplotlib
        img_rgb = cv2.cvtColor(img_with_boxes, cv2.COLOR_BGR2RGB)
        plt.subplot(1, sample_count, i + 1)
        plt.imshow(img_rgb)
        plt.title(base_name)
        plt.axis('off')
    plt.suptitle("Sample Images with Bounding Boxes")
    plt.show()

def count_all_labels(labels_dir):
    """
    Đếm số bounding box theo lớp từ tất cả các file label trong folder.
    """
    counts = Counter()
    label_files = [f for f in os.listdir(labels_dir) if f.endswith(".txt")]
    for label_file in label_files:
        full_label_path = os.path.join(labels_dir, label_file)
        boxes = parse_label_file(full_label_path)
        for box in boxes:
            cls = box[0]
            counts[cls] += 1
    return counts

def visualize_label_counts(counts):
    """
    Visualize số lượng bounding boxes theo lớp dưới dạng biểu đồ cột.
    """
    # Sắp xếp các lớp theo thứ tự key
    classes = sorted(counts.keys())
    class_labels = [class_names.get(c, str(c)) for c in classes]
    values = [counts[c] for c in classes]
    plt.figure(figsize=(10, 6))
    plt.bar(class_labels, values, color='skyblue')
    plt.xlabel("Lớp")
    plt.ylabel("Số lượng bounding boxes")
    plt.title("Phân bố bounding boxes theo lớp")
    plt.show()

if __name__ == "__main__":
    # Visualize mẫu ảnh kèm bounding box
    print("Visualize sample images with bounding boxes...")
    visualize_samples(merged_images_dir, merged_labels_dir, sample_count=5)

    # Đếm số bounding box theo lớp
    counts = count_all_labels(merged_labels_dir)
    print("Số lượng bounding boxes theo lớp:", counts)

    # Visualize biểu đồ số lượng bounding box theo lớp
    visualize_label_counts(counts)
# Out:
# Visualize sample images with bounding boxes...
# Số lượng bounding boxes theo lớp: Counter({6: 24078, 3: 19103, 1: 13476, 5: 10930, 4: 5632, 2: 2699, 0: 58})

# %% [markdown]
# ## Cải tiến merge cả train, valid, test. Có check validate, thống kê

# %%
import os
import shutil
import random
import matplotlib.pyplot as plt
import logging

# ------------------------------
# CẤU HÌNH LOGGING
# ------------------------------
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# ------------------------------
# CÁC MAPPING CHO DATASET
# ------------------------------
student_mapping = {
    0: 'drinking',
    1: 'raising_hand',
    2: 'sleeping',
    3: 'using_computer',
    4: 'using_phone',
    5: 'writing'
}

scb_mapping = {
    0: 'hand-raising',  # sẽ map sang 'raising_hand'
    1: 'read',          # nếu cần chuyển thành 'reading' thì thêm xử lý
    2: 'write'          # sẽ map sang 'writing'
}

# Unified mapping: sử dụng định nghĩa của Student, bổ sung lớp 'read'
unified_mapping = {
    'drinking': 0,
    'raising_hand': 1,
    'sleeping': 2,
    'using_computer': 3,
    'using_phone': 4,
    'writing': 5,
    'read': 6
}

# ------------------------------
# HÀM XỬ LÝ ANNOTATION SCB
# ------------------------------
def update_scb_annotation_line(line):
    """
    Chuyển đổi một dòng annotation của SCB sang unified mapping.
    Dòng annotation có định dạng: "cls x_center y_center width height"
    """
    parts = line.strip().split()
    if len(parts) < 5:
        return line  # nếu dòng không hợp lệ
    orig_cls = int(parts[0])
    
    # Lấy tên nhãn theo SCB
    class_name = scb_mapping.get(orig_cls)
    if class_name is None:
        return line
    
    # Map tên nhãn:
    # hand-raising -> raising_hand, write -> writing (read giữ nguyên)
    if class_name == 'hand-raising':
        class_name = 'raising_hand'
    elif class_name == 'write':
        class_name = 'writing'
    
    new_cls = unified_mapping.get(class_name)
    parts[0] = str(new_cls)
    return " ".join(parts)

def process_scb_annotations(scb_labels_dir, output_labels_dir):
    """
    Chuyển đổi toàn bộ file annotation của SCB từ scb_labels_dir sang output_labels_dir.
    """
    if not os.path.exists(output_labels_dir):
        os.makedirs(output_labels_dir)
    for filename in os.listdir(scb_labels_dir):
        if not filename.endswith(".txt"):
            continue
        input_path = os.path.join(scb_labels_dir, filename)
        output_path = os.path.join(output_labels_dir, filename)
        try:
            with open(input_path, 'r') as f:
                lines = f.readlines()
            updated_lines = [update_scb_annotation_line(line) for line in lines]
            with open(output_path, 'w') as f:
                f.write("\n".join(updated_lines))
            logging.info(f"Processed SCB annotation: {filename}")
        except Exception as e:
            logging.error(f"Lỗi xử lý file {filename}: {e}")

# ------------------------------
# HÀM COPY FILE AN TOÀN (SAFE COPY) VỚI XỬ LÝ TRÙNG TÊN
# ------------------------------
def safe_copy(src_path, dest_dir, prefix=""):
    """
    Copy file từ src_path sang dest_dir.
    Nếu file đã tồn tại, tự động đổi tên để tránh ghi đè (thêm prefix + _dup).
    Trả về tên file đích.
    """
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)
    filename = os.path.basename(src_path)
    dest_path = os.path.join(dest_dir, prefix + filename)
    base, ext = os.path.splitext(prefix + filename)
    counter = 1
    # Nếu file tồn tại, thêm hậu tố _dup{counter}
    while os.path.exists(dest_path):
        dest_path = os.path.join(dest_dir, f"{base}_dup{counter}{ext}")
        counter += 1
    try:
        shutil.copy(src_path, dest_path)
        return os.path.basename(dest_path)
    except Exception as e:
        logging.error(f"Lỗi copy file {src_path} -> {dest_path}: {e}")
        return None

# ------------------------------
# HÀM THỐNG KÊ TỪ FOLDER
# ------------------------------
def get_files_stats(directory, valid_extensions):
    """
    Lấy danh sách file (chỉ tên file) từ directory có đuôi trong valid_extensions.
    """
    files = [f for f in os.listdir(directory) 
             if os.path.splitext(f)[1].lower() in valid_extensions]
    total = len(files)
    # Trong 1 folder, tên file thường đã duy nhất, nhưng nếu hợp nhất từ nhiều nguồn thì có thể trùng
    freq = {}
    duplicates = []
    for f in files:
        freq[f] = freq.get(f, 0) + 1
        if freq[f] > 1 and f not in duplicates:
            duplicates.append(f)
    return {"total": total, "files": files, "duplicates": duplicates}

def check_match(images_dir, labels_dir, image_exts, label_ext=".txt"):
    # Lấy danh sách tên file (không bao gồm phần mở rộng)
    image_files = [os.path.splitext(f)[0] for f in os.listdir(images_dir) 
                   if os.path.splitext(f)[1].lower() in image_exts]
    label_files = [os.path.splitext(f)[0] for f in os.listdir(labels_dir) 
                   if f.endswith(label_ext)]
    images_set = set(image_files)
    labels_set = set(label_files)
    images_without_labels = list(images_set - labels_set)
    labels_without_images = list(labels_set - images_set)
    # Trả về dictionary thay vì tuple
    return {"images_without_labels": images_without_labels, 
            "labels_without_images": labels_without_images}


def visualize_stats(stats_dict, title):
    """
    Vẽ biểu đồ cột hiển thị thống kê:
      - Total files
      - Số file duplicate
      - Số file không có đối ứng (nếu có)
    stats_dict: {'Images': {...}, 'Labels': {...}, 'Mismatch': {...}}
    """
    labels = []
    values = []
    for key, stat in stats_dict.items():
        # Nếu key có chứa từ "Mismatch", xử lý như một dictionary mismatch
        if "Mismatch" in key:
            # Lấy danh sách file ảnh không có label và label không có ảnh từ dictionary mismatch
            mismatch_count = len(stat.get("images_without_labels", [])) + len(stat.get("labels_without_images", []))
            labels.append(key)  # Dùng key gốc cho mục Mismatch
            values.append(mismatch_count)
        else:
            # Đối với các mục khác, ta giả định stat có khóa "total" và "duplicates"
            labels.append(key + "\n(Total)")
            values.append(stat["total"])
            labels.append(key + "\n(Duplicate)")
            values.append(len(stat["duplicates"]))
            
    plt.figure(figsize=(8,6))
    plt.bar(labels, values, color='skyblue')
    plt.ylabel("Số lượng")
    plt.title(title)
    plt.show()

# ------------------------------
# ĐƯỜNG DẪN DATASET NGUỒN VÀ MERGED
# ------------------------------
# Dataset Student (đã có sẵn) - các split
student_train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/images"
student_train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels"
student_valid_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/images"
student_valid_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels"
student_test_images_dir  = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/images"
student_test_labels_dir  = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels"

# Dataset SCB ban đầu - các split
scb_train_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/train"
scb_train_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/train"
scb_valid_labels_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/val"
scb_valid_images_dir = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/val"
scb_test_labels_dir  = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/labels/test"
scb_test_images_dir  = "/home/minhnv/Documents/ntt/AiIot/FinalPorject/CodingYOLOv12_Ver2/Dataset/SCB5-HandRise-Read-Write/images/test"

# Folder output cho dataset merged (Student đã merge SCB)
merged_dataset_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/merged_dataset_student_scb"
merged_images_dir = os.path.join(merged_dataset_dir, "images")
merged_labels_dir = os.path.join(merged_dataset_dir, "labels")

os.makedirs(merged_images_dir, exist_ok=True)
os.makedirs(merged_labels_dir, exist_ok=True)

# ------------------------------
# HÀM THỐNG KÊ TRƯỚC KHI MERGE (TỔNG HỢP TỪ CÁC SPLIT)
# ------------------------------
valid_img_exts = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

def aggregate_stats(dirs, valid_exts, file_type="Images"):
    """
    Thu thập thống kê từ danh sách các folder.
    Trả về 1 dict với tổng số file và danh sách các file (dùng để tính duplicates).
    """
    all_files = []
    for d in dirs:
        try:
            files = [f for f in os.listdir(d) if os.path.splitext(f)[1].lower() in valid_exts]
            all_files.extend(files)
        except Exception as e:
            logging.error(f"Lỗi đọc folder {d}: {e}")
    freq = {}
    duplicates = []
    for f in all_files:
        freq[f] = freq.get(f, 0) + 1
        if freq[f] > 1 and f not in duplicates:
            duplicates.append(f)
    return {"total": len(all_files), "files": all_files, "duplicates": duplicates}

# Các folder nguồn
student_img_dirs = [student_train_images_dir, student_valid_images_dir, student_test_images_dir]
student_lbl_dirs = [student_train_labels_dir, student_valid_labels_dir, student_test_labels_dir]
scb_img_dirs = [scb_train_images_dir, scb_valid_images_dir, scb_test_images_dir]
scb_lbl_dirs = [scb_train_labels_dir, scb_valid_labels_dir, scb_test_labels_dir]

# Aggregate stats trước merge
pre_merge_student_images = aggregate_stats(student_img_dirs, valid_img_exts, "Images")
pre_merge_student_labels = aggregate_stats(student_lbl_dirs, [".txt"], "Labels")
pre_merge_scb_images = aggregate_stats(scb_img_dirs, valid_img_exts, "Images")
pre_merge_scb_labels = aggregate_stats(scb_lbl_dirs, [".txt"], "Labels")

# Kiểm tra sự không khớp giữa ảnh và label cho mỗi nguồn
def get_mismatch_stats(images_dir, labels_dir):
    imgs_without_lbl, lbls_without_img = check_match(images_dir, labels_dir, valid_img_exts)
    return {"images_without_labels": imgs_without_lbl, "labels_without_images": lbls_without_img}

# Ví dụ: lấy mismatch cho Student train (có thể lặp lại cho từng split)
student_train_mismatch = get_mismatch_stats(student_train_images_dir, student_train_labels_dir)
scb_train_mismatch = get_mismatch_stats(scb_train_images_dir, scb_train_labels_dir)

# Visualize thống kê trước merge
pre_merge_stats = {
    "Student Images": pre_merge_student_images,
    "Student Labels": pre_merge_student_labels,
    "SCB Images": pre_merge_scb_images,
    "SCB Labels": pre_merge_scb_labels,
    "Mismatch (Student Train)": student_train_mismatch,
    "Mismatch (SCB Train)": scb_train_mismatch
}

visualize_stats(pre_merge_stats, "Thống kê trước khi merge")

# ------------------------------
# BƯỚC MERGE DỮ LIỆU
# ------------------------------

# (A) COPY ANNOTATION CỦA STUDENT (từ các split) sang merged
for folder in student_lbl_dirs:
    for filename in os.listdir(folder):
        if filename.endswith(".txt"):
            safe_copy(os.path.join(folder, filename), merged_labels_dir, prefix="stu_")

# (B) PROCESS ANNOTATION CỦA SCB (từ các split) và copy sang merged
for folder in scb_lbl_dirs:
    process_scb_annotations(folder, merged_labels_dir)

# (C) COPY ẢNH CỦA STUDENT (từ các split) sang merged
for folder in student_img_dirs:
    for filename in os.listdir(folder):
        ext = os.path.splitext(filename)[1].lower()
        if ext in valid_img_exts:
            safe_copy(os.path.join(folder, filename), merged_images_dir, prefix="stu_")

# (D) COPY ẢNH CỦA SCB (từ các split) sang merged
for folder in scb_img_dirs:
    for filename in os.listdir(folder):
        ext = os.path.splitext(filename)[1].lower()
        if ext in valid_img_exts:
            safe_copy(os.path.join(folder, filename), merged_images_dir, prefix="scb_")

logging.info("Merge dataset thành công!")

# ------------------------------
# THỐNG KÊ SAU KHI MERGE
# ------------------------------
post_merge_images = get_files_stats(merged_images_dir, valid_img_exts)
post_merge_labels = get_files_stats(merged_labels_dir, [".txt"])
post_merge_mismatch = check_match(merged_images_dir, merged_labels_dir, valid_img_exts)

post_merge_stats = {
    "Images": post_merge_images,
    "Labels": post_merge_labels,
    "Mismatch": post_merge_mismatch
}

visualize_stats(post_merge_stats, "Thống kê sau khi merge")
# Out:
# INFO: Processed SCB annotation: 1424007.txt
# INFO: Processed SCB annotation: 1262016.txt
# INFO: Processed SCB annotation: 1000062.txt
# INFO: Processed SCB annotation: 0013005.txt
# INFO: Processed SCB annotation: 0081_001792.txt
# INFO: Processed SCB annotation: 9_001110.txt
# INFO: Processed SCB annotation: 1429041.txt
# INFO: Processed SCB annotation: 3005124.txt
# INFO: Processed SCB annotation: 12_001362.txt
# INFO: Processed SCB annotation: 3005298.txt
# INFO: Processed SCB annotation: 15_002004.txt
# INFO: Processed SCB annotation: 3004055.txt
# INFO: Processed SCB annotation: 133_000731.txt
# INFO: Processed SCB annotation: 1358001.txt
# INFO: Processed SCB annotation: 3005161.txt
# INFO: Processed SCB annotation: 3004102.txt
# INFO: Processed SCB annotation: 0105021.txt
# INFO: Processed SCB annotation: 18_000752.txt
# INFO: Processed SCB annotation: 1297032.txt
# INFO: Processed SCB annotation: 130_001520.txt
# INFO: Processed SCB annotation: 21_001745.txt
# INFO: Processed SCB annotation: 1311024.txt
# INFO: Processed SCB annotation: 0105040.txt
# INFO: Processed SCB annotation: 1332016.txt
# INFO: Processed SCB annotation: 1429024.txt
# INFO: Processed SCB annotation: 1302036.txt
# INFO: Processed SCB annotation: 0089_001759.txt
# INFO: Processed SCB annotation: 0081_001789.txt
# INFO: Processed SCB annotation: 0089_002232.txt
# INFO: Processed SCB annotation: 13160041.txt
# INFO: Processed SCB annotation: 3000069.txt
# INFO: Processed SCB annotation: 1249023.txt
# INFO: Processed SCB annotation: 0106010.txt
# INFO: Processed SCB annotation: 0204023.txt
# INFO: Processed SCB annotation: 0013003.txt
# INFO: Processed SCB annotation: 0800010.txt
# INFO: Processed SCB annotation: 1243010.txt
# INFO: Processed SCB annotation: 0100016.txt
# INFO: Processed SCB annotation: 2109008.txt
# INFO: Processed SCB annotation: 3005122.txt
# INFO: Processed SCB annotation: 3004098.txt
# INFO: Processed SCB annotation: 1298046.txt
# INFO: Processed SCB annotation: 1429020.txt
# INFO: Processed SCB annotation: 17_001705.txt
# INFO: Processed SCB annotation: 18_001499.txt
# INFO: Processed SCB annotation: 12_001388.txt
# INFO: Processed SCB annotation: 57_002209.txt
# INFO: Processed SCB annotation: 1249057.txt
# INFO: Processed SCB annotation: 1270053.txt
# INFO: Processed SCB annotation: 16_000889.txt
# INFO: Processed SCB annotation: 1249058.txt
# INFO: Processed SCB annotation: 1274046.txt
# INFO: Processed SCB annotation: 1314035.txt
# INFO: Processed SCB annotation: 3004121.txt
# INFO: Processed SCB annotation: 1313037.txt
# INFO: Processed SCB annotation: 0013012.txt
# INFO: Processed SCB annotation: 1318007.txt
# INFO: Processed SCB annotation: 1429014.txt
# INFO: Processed SCB annotation: 1315054.txt
# INFO: Processed SCB annotation: 131_001904.txt
# INFO: Processed SCB annotation: 0009037.txt
# INFO: Processed SCB annotation: 3005024.txt
# INFO: Processed SCB annotation: 0089_001613.txt
# INFO: Processed SCB annotation: 3004063.txt
# INFO: Processed SCB annotation: 15_001509.txt
# INFO: Processed SCB annotation: 0202004.txt
# INFO: Processed SCB annotation: 0009054.txt
# INFO: Processed SCB annotation: 11_001111.txt
# INFO: Processed SCB annotation: 3004131.txt
# INFO: Processed SCB annotation: 1270010.txt
# INFO: Processed SCB annotation: 0086_000364.txt
# INFO: Processed SCB annotation: 130_000578.txt
# INFO: Processed SCB annotation: 1331036.txt
# INFO: Processed SCB annotation: 1317011.txt
# INFO: Processed SCB annotation: 57_002233.txt
# INFO: Processed SCB annotation: 3003121.txt
# INFO: Processed SCB annotation: 21_000808.txt
# INFO: Processed SCB annotation: 1249033.txt
# INFO: Processed SCB annotation: 0101054.txt
# INFO: Processed SCB annotation: 60_001404.txt
# INFO: Processed SCB annotation: 0086_000618.txt
# INFO: Processed SCB annotation: 8_002238.txt
# INFO: Processed SCB annotation: 1331047.txt
# INFO: Processed SCB annotation: 1249046.txt
# INFO: Processed SCB annotation: 3003097.txt
# INFO: Processed SCB annotation: 1249051.txt
# INFO: Processed SCB annotation: 3004237.txt
# INFO: Processed SCB annotation: 131_000823.txt
# INFO: Processed SCB annotation: 0081_000467.txt
# INFO: Processed SCB annotation: 1340016.txt
# INFO: Processed SCB annotation: 1283043.txt
# INFO: Processed SCB annotation: 0091_000184.txt
# INFO: Processed SCB annotation: 0800029.txt
# INFO: Processed SCB annotation: 0100065.txt
# INFO: Processed SCB annotation: 1128029.txt
# INFO: Processed SCB annotation: 130_000276.txt
# INFO: Processed SCB annotation: 1121038.txt
# INFO: Processed SCB annotation: 2110038.txt
# INFO: Processed SCB annotation: 1266058.txt
# INFO: Processed SCB annotation: 1309007.txt
# INFO: Processed SCB annotation: 1358019.txt
# INFO: Processed SCB annotation: 0091_002210.txt
# INFO: Processed SCB annotation: 134_000483.txt
# INFO: Processed SCB annotation: 0404021.txt
# INFO: Processed SCB annotation: 1319013.txt
# INFO: Processed SCB annotation: 0201007.txt
# INFO: Processed SCB annotation: 1128006.txt
# INFO: Processed SCB annotation: 1333039.txt
# INFO: Processed SCB annotation: 0100063.txt
# INFO: Processed SCB annotation: 0087_000930.txt
# INFO: Processed SCB annotation: 11_000558.txt
# INFO: Processed SCB annotation: 0086_002337.txt
# INFO: Processed SCB annotation: 3003043.txt
# INFO: Processed SCB annotation: 1302015.txt
# INFO: Processed SCB annotation: 0201017.txt
# INFO: Processed SCB annotation: 16_000961.txt
# INFO: Processed SCB annotation: 1330048.txt
# INFO: Processed SCB annotation: 1431018.txt
# INFO: Processed SCB annotation: 139_001444.txt
# INFO: Processed SCB annotation: 0081_001262.txt
# INFO: Processed SCB annotation: 0087_002145.txt
# INFO: Processed SCB annotation: 3003039.txt
# INFO: Processed SCB annotation: 0400008.txt
# INFO: Processed SCB annotation: 18_000804.txt
# INFO: Processed SCB annotation: 1120008.txt
# INFO: Processed SCB annotation: 0009022.txt
# INFO: Processed SCB annotation: 1319023.txt
# INFO: Processed SCB annotation: 0089_001744.txt
# INFO: Processed SCB annotation: 1256004.txt
# INFO: Processed SCB annotation: 1257016.txt
# INFO: Processed SCB annotation: 1270082.txt
# INFO: Processed SCB annotation: 1290002.txt
# INFO: Processed SCB annotation: 0025056.txt
# INFO: Processed SCB annotation: 13160040.txt
# INFO: Processed SCB annotation: 1379035.txt
# INFO: Processed SCB annotation: 15_000470.txt
# INFO: Processed SCB annotation: 1332037.txt
# INFO: Processed SCB annotation: 3005233.txt
# INFO: Processed SCB annotation: 130_000258.txt
# INFO: Processed SCB annotation: 1303031.txt
# INFO: Processed SCB annotation: 1340009.txt
# INFO: Processed SCB annotation: 1399021.txt
# INFO: Processed SCB annotation: 1317029.txt
# INFO: Processed SCB annotation: 1128020.txt
# INFO: Processed SCB annotation: 1298048.txt
# INFO: Processed SCB annotation: 3005245.txt
# INFO: Processed SCB annotation: 0089_002186.txt
# INFO: Processed SCB annotation: 1363038.txt
# INFO: Processed SCB annotation: 1315042.txt
# INFO: Processed SCB annotation: 06010008.txt
# INFO: Processed SCB annotation: 1000047.txt
# INFO: Processed SCB annotation: 0091_001461.txt
# INFO: Processed SCB annotation: 60_001568.txt
# INFO: Processed SCB annotation: 18_000759.txt
# INFO: Processed SCB annotation: 1252034.txt
# INFO: Processed SCB annotation: 8_001338.txt
# INFO: Processed SCB annotation: 1297031.txt
# INFO: Processed SCB annotation: 0023025.txt
# INFO: Processed SCB annotation: 1317006.txt
# INFO: Processed SCB annotation: 3003098.txt
# INFO: Processed SCB annotation: 0016009.txt
# INFO: Processed SCB annotation: 1294006.txt
# INFO: Processed SCB annotation: 0404013.txt
# INFO: Processed SCB annotation: 3004045.txt
# INFO: Processed SCB annotation: 18_000926.txt
# INFO: Processed SCB annotation: 1252002.txt
# INFO: Processed SCB annotation: 3000024.txt
# INFO: Processed SCB annotation: 0086_002224.txt
# INFO: Processed SCB annotation: 16_000939.txt
# INFO: Processed SCB annotation: 010725.txt
# INFO: Processed SCB annotation: 1283028.txt
# INFO: Processed SCB annotation: 0087_001171.txt
# INFO: Processed SCB annotation: 0089_000519.txt
# INFO: Processed SCB annotation: 0106029.txt
# INFO: Processed SCB annotation: 1281048.txt
# INFO: Processed SCB annotation: 134_001544.txt
# INFO: Processed SCB annotation: 0400033.txt
# INFO: Processed SCB annotation: 12_001612.txt
# INFO: Processed SCB annotation: 3000196.txt
# INFO: Processed SCB annotation: 0106032.txt
# INFO: Processed SCB annotation: 3000193.txt
# INFO: Processed SCB annotation: 1281025.txt
# INFO: Processed SCB annotation: 0009001.txt
# INFO: Processed SCB annotation: 3000041.txt
# INFO: Processed SCB annotation: 12_002550.txt
# INFO: Processed SCB annotation: 3000139.txt
# INFO: Processed SCB annotation: 130_001684.txt
# INFO: Processed SCB annotation: 0205002.txt
# INFO: Processed SCB annotation: 1266061.txt
# INFO: Processed SCB annotation: 3003078.txt
# INFO: Processed SCB annotation: 0800033.txt
# INFO: Processed SCB annotation: 130_000870.txt
# INFO: Processed SCB annotation: 8_000803.txt
# INFO: Processed SCB annotation: 1424008.txt
# INFO: Processed SCB annotation: 1431005.txt
# INFO: Processed SCB annotation: 0015010.txt
# INFO: Processed SCB annotation: 12_001380.txt
# INFO: Processed SCB annotation: 17_000142.txt
# INFO: Processed SCB annotation: 0400031.txt
# INFO: Processed SCB annotation: 134_001874.txt
# INFO: Processed SCB annotation: 3005031.txt
# INFO: Processed SCB annotation: 60_001462.txt
# INFO: Processed SCB annotation: 1283019.txt
# INFO: Processed SCB annotation: 3000123.txt
# INFO: Processed SCB annotation: 3004140.txt
# INFO: Processed SCB annotation: 130_001687.txt
# INFO: Processed SCB annotation: 1000006.txt
# INFO: Processed SCB annotation: 1283035.txt
# INFO: Processed SCB annotation: 0086_002318.txt
# INFO: Processed SCB annotation: 0106013.txt
# INFO: Processed SCB annotation: 1333042.txt
# INFO: Processed SCB annotation: 11_002018.txt
# INFO: Processed SCB annotation: 130_000670.txt
# INFO: Processed SCB annotation: 0089_000121.txt
# INFO: Processed SCB annotation: 60_000985.txt
# INFO: Processed SCB annotation: 17_001380.txt
# INFO: Processed SCB annotation: 3003073.txt
# INFO: Processed SCB annotation: 1246035.txt
# INFO: Processed SCB annotation: 2_000290.txt
# INFO: Processed SCB annotation: 0011015.txt
# INFO: Processed SCB annotation: 1292002.txt
# INFO: Processed SCB annotation: 1121015.txt
# INFO: Processed SCB annotation: 57_001588.txt
# INFO: Processed SCB annotation: 0089_000029.txt
# INFO: Processed SCB annotation: 57_002215.txt
# INFO: Processed SCB annotation: 1307001.txt
# INFO: Processed SCB annotation: 18_002250.txt
# INFO: Processed SCB annotation: 3004075.txt
# INFO: Processed SCB annotation: 60_001213.txt
# INFO: Processed SCB annotation: 3000144.txt
# INFO: Processed SCB annotation: 3004049.txt
# INFO: Processed SCB annotation: 21_001644.txt
# INFO: Processed SCB annotation: 60_001560.txt
# INFO: Processed SCB annotation: 130_001143.txt
# INFO: Processed SCB annotation: 0203019.txt
# INFO: Processed SCB annotation: 1318003.txt
# INFO: Processed SCB annotation: 1399008.txt
# INFO: Processed SCB annotation: 11_000597.txt
# INFO: Processed SCB annotation: 130_001965.txt
# INFO: Processed SCB annotation: 0089_000776.txt
# INFO: Processed SCB annotation: 0102042.txt
# INFO: Processed SCB annotation: 17_000144.txt
# INFO: Processed SCB annotation: 1265092.txt
# INFO: Processed SCB annotation: 06000090.txt
# INFO: Processed SCB annotation: 0401073.txt
# INFO: Processed SCB annotation: 1307011.txt
# INFO: Processed SCB annotation: 0089_000857.txt
# INFO: Processed SCB annotation: 130_000945.txt
# INFO: Processed SCB annotation: 1256044.txt
# INFO: Processed SCB annotation: 1298059.txt
# INFO: Processed SCB annotation: 0100058.txt
# INFO: Processed SCB annotation: 133_001720.txt
# INFO: Processed SCB annotation: 1120060.txt
# INFO: Processed SCB annotation: 4_001191.txt
# INFO: Processed SCB annotation: 19_002111.txt
# INFO: Processed SCB annotation: 0025002.txt
# INFO: Processed SCB annotation: 1424017.txt
# INFO: Processed SCB annotation: 1249039.txt
# INFO: Processed SCB annotation: 18_001799.txt
# INFO: Processed SCB annotation: 0025016.txt
# INFO: Processed SCB annotation: 1331016.txt
# INFO: Processed SCB annotation: 0401041.txt
# INFO: Processed SCB annotation: 1266027.txt
# INFO: Processed SCB annotation: 1315031.txt
# INFO: Processed SCB annotation: 0089_001605.txt
# INFO: Processed SCB annotation: 1304040.txt
# INFO: Processed SCB annotation: 16_000775.txt
# INFO: Processed SCB annotation: 1249009.txt
# INFO: Processed SCB annotation: 1319009.txt
# INFO: Processed SCB annotation: 1294015.txt
# INFO: Processed SCB annotation: 133_002068.txt
# INFO: Processed SCB annotation: 3000153.txt
# INFO: Processed SCB annotation: 1265053.txt
# INFO: Processed SCB annotation: 1246044.txt
# INFO: Processed SCB annotation: 57_001105.txt
# INFO: Processed SCB annotation: 0013016.txt
# INFO: Processed SCB annotation: 1312027.txt
# INFO: Processed SCB annotation: 06010003.txt
# INFO: Processed SCB annotation: 1297004.txt
# INFO: Processed SCB annotation: 1267087.txt
# INFO: Processed SCB annotation: 3000032.txt
# INFO: Processed SCB annotation: 3000004.txt
# INFO: Processed SCB annotation: 3000080.txt
# INFO: Processed SCB annotation: 3003085.txt
# INFO: Processed SCB annotation: 133_000663.txt
# INFO: Processed SCB annotation: 0404050.txt
# INFO: Processed SCB annotation: 8_001095.txt
# INFO: Processed SCB annotation: 21_001751.txt
# INFO: Processed SCB annotation: 130_000909.txt
# INFO: Processed SCB annotation: 131_000679.txt
# INFO: Processed SCB annotation: 1130021.txt
# INFO: Processed SCB annotation: 0401037.txt
# INFO: Processed SCB annotation: 0087_002147.txt
# INFO: Processed SCB annotation: 1301011.txt
# INFO: Processed SCB annotation: 3000205.txt
# INFO: Processed SCB annotation: 0089_001644.txt
# INFO: Processed SCB annotation: 1281011.txt
# INFO: Processed SCB annotation: 1262029.txt
# INFO: Processed SCB annotation: 1267121.txt
# INFO: Processed SCB annotation: 1304023.txt
# INFO: Processed SCB annotation: 1130024.txt
# INFO: Processed SCB annotation: 0204021.txt
# INFO: Processed SCB annotation: 0102049.txt
# INFO: Processed SCB annotation: 06010022.txt
# INFO: Processed SCB annotation: 18_000232.txt
# INFO: Processed SCB annotation: 1257034.txt
# INFO: Processed SCB annotation: 19_001382.txt
# INFO: Processed SCB annotation: 1317003.txt
# INFO: Processed SCB annotation: 12_002090.txt
# INFO: Processed SCB annotation: 1246038.txt
# INFO: Processed SCB annotation: 1249006.txt
# INFO: Processed SCB annotation: 131_000603.txt
# INFO: Processed SCB annotation: 0401051.txt
# INFO: Processed SCB annotation: 0024039.txt
# INFO: Processed SCB annotation: 0205008.txt
# INFO: Processed SCB annotation: 15_000417.txt
# INFO: Processed SCB annotation: 1262021.txt
# INFO: Processed SCB annotation: 18_001713.txt
# INFO: Processed SCB annotation: 1429017.txt
# INFO: Processed SCB annotation: 0025041.txt
# INFO: Processed SCB annotation: 1270020.txt
# INFO: Processed SCB annotation: 9_000382.txt
# INFO: Processed SCB annotation: 1295001.txt
# INFO: Processed SCB annotation: 1246029.txt
# INFO: Processed SCB annotation: 18_001914.txt
# INFO: Processed SCB annotation: 1314002.txt
# INFO: Processed SCB annotation: 1319003.txt
# INFO: Processed SCB annotation: 1305014.txt
# INFO: Processed SCB annotation: 1332013.txt
# INFO: Processed SCB annotation: 3005009.txt
# INFO: Processed SCB annotation: 3000070.txt
# INFO: Processed SCB annotation: 1243008.txt
# INFO: Processed SCB annotation: 133_001493.txt
# INFO: Processed SCB annotation: 2110014.txt
# INFO: Processed SCB annotation: 1128022.txt
# INFO: Processed SCB annotation: 1395013.txt
# INFO: Processed SCB annotation: 148_000299.txt
# INFO: Processed SCB annotation: 1265042.txt
# INFO: Processed SCB annotation: 1333037.txt
# INFO: Processed SCB annotation: 1270058.txt
# INFO: Processed SCB annotation: 0091_001453.txt
# INFO: Processed SCB annotation: 18_002271.txt
# INFO: Processed SCB annotation: 0087_000773.txt
# INFO: Processed SCB annotation: 1331032.txt
# INFO: Processed SCB annotation: 2109016.txt
# INFO: Processed SCB annotation: 0105019.txt
# INFO: Processed SCB annotation: 0089_000030.txt
# INFO: Processed SCB annotation: 0403042.txt
# INFO: Processed SCB annotation: 0086_002324.txt
# INFO: Processed SCB annotation: 0202006.txt
# INFO: Processed SCB annotation: 1424013.txt
# INFO: Processed SCB annotation: 0401001.txt
# INFO: Processed SCB annotation: 0401054.txt
# INFO: Processed SCB annotation: 0009028.txt
# INFO: Processed SCB annotation: 3005242.txt
# INFO: Processed SCB annotation: 0081_001512.txt
# INFO: Processed SCB annotation: 1243012.txt
# INFO: Processed SCB annotation: 1246050.txt
# INFO: Processed SCB annotation: 1000031.txt
# INFO: Processed SCB annotation: 0800005.txt
# INFO: Processed SCB annotation: 1301003.txt
# INFO: Processed SCB annotation: 1265032.txt
# INFO: Processed SCB annotation: 0102028.txt
# INFO: Processed SCB annotation: 1303011.txt
# INFO: Processed SCB annotation: 20_001845.txt
# INFO: Processed SCB annotation: 3003059.txt
# INFO: Processed SCB annotation: 1257005.txt
# INFO: Processed SCB annotation: 0101059.txt
# INFO: Processed SCB annotation: 1301009.txt
# INFO: Processed SCB annotation: 1429025.txt
# INFO: Processed SCB annotation: 1256034.txt
# INFO: Processed SCB annotation: 0089_001631.txt
# INFO: Processed SCB annotation: 0088_001152.txt
# INFO: Processed SCB annotation: 9_001118.txt
# INFO: Processed SCB annotation: 132_001287.txt
# INFO: Processed SCB annotation: 0081_001508.txt
# INFO: Processed SCB annotation: 1120012.txt
# INFO: Processed SCB annotation: 0106023.txt
# INFO: Processed SCB annotation: 1303014.txt
# INFO: Processed SCB annotation: 3003168.txt
# INFO: Processed SCB annotation: 15_000438.txt
# INFO: Processed SCB annotation: 0089_001656.txt
# INFO: Processed SCB annotation: 0100057.txt
# INFO: Processed SCB annotation: 133_001112.txt
# INFO: Processed SCB annotation: 3000029.txt
# INFO: Processed SCB annotation: 0106001.txt
# INFO: Processed SCB annotation: 1270059.txt
# INFO: Processed SCB annotation: 06000044.txt
# INFO: Processed SCB annotation: 3000131.txt
# INFO: Processed SCB annotation: 1274022.txt
# INFO: Processed SCB annotation: 0403047.txt
# INFO: Processed SCB annotation: 0086_002325.txt
# INFO: Processed SCB annotation: 1395010.txt
# INFO: Processed SCB annotation: 130_001983.txt
# INFO: Processed SCB annotation: 8_001092.txt
# INFO: Processed SCB annotation: 1358018.txt
# INFO: Processed SCB annotation: 0091_002115.txt
# INFO: Processed SCB annotation: 0006016.txt
# INFO: Processed SCB annotation: 1312026.txt
# INFO: Processed SCB annotation: 1000014.txt
# INFO: Processed SCB annotation: 1000009.txt
# INFO: Processed SCB annotation: 13160050.txt
# INFO: Processed SCB annotation: 1000044.txt
# INFO: Processed SCB annotation: 1262024.txt
# INFO: Processed SCB annotation: 1302014.txt
# INFO: Processed SCB annotation: 16_001829.txt
# INFO: Processed SCB annotation: 60_001566.txt
# INFO: Processed SCB annotation: 3005284.txt
# INFO: Processed SCB annotation: 0100059.txt
# INFO: Processed SCB annotation: 1000050.txt
# INFO: Processed SCB annotation: 1311001.txt
# INFO: Processed SCB annotation: 1000017.txt
# INFO: Processed SCB annotation: 3003001.txt
# INFO: Processed SCB annotation: 1265047.txt
# INFO: Processed SCB annotation: 1305009.txt
# INFO: Processed SCB annotation: 1266044.txt
# INFO: Processed SCB annotation: 1340007.txt
# INFO: Processed SCB annotation: 1121030.txt
# INFO: Processed SCB annotation: 3004036.txt
# INFO: Processed SCB annotation: 11_001279.txt
# INFO: Processed SCB annotation: 0088_001511.txt
# INFO: Processed SCB annotation: 1312039.txt
# INFO: Processed SCB annotation: 133_000995.txt
# INFO: Processed SCB annotation: 18_002463.txt
# INFO: Processed SCB annotation: 16_000859.txt
# INFO: Processed SCB annotation: 0086_000593.txt
# INFO: Processed SCB annotation: 3000143.txt
# INFO: Processed SCB annotation: 1281009.txt
# INFO: Processed SCB annotation: 21_002391.txt
# INFO: Processed SCB annotation: 130_001464.txt
# INFO: Processed SCB annotation: 0105014.txt
# INFO: Processed SCB annotation: 0020004.txt
# INFO: Processed SCB annotation: 0404048.txt
# INFO: Processed SCB annotation: 3000197.txt
# INFO: Processed SCB annotation: 1270068.txt
# INFO: Processed SCB annotation: 1313029.txt
# INFO: Processed SCB annotation: 13160043.txt
# INFO: Processed SCB annotation: 06000030.txt
# INFO: Processed SCB annotation: 4_001295.txt
# INFO: Processed SCB annotation: 3004159.txt
# INFO: Processed SCB annotation: 3000098.txt
# INFO: Processed SCB annotation: 0025024.txt
# INFO: Processed SCB annotation: 0081_000399.txt
# INFO: Processed SCB annotation: 1120002.txt
# INFO: Processed SCB annotation: 1309004.txt
# INFO: Processed SCB annotation: 9_000762.txt
# INFO: Processed SCB annotation: 3005016.txt
# INFO: Processed SCB annotation: 0401044.txt
# INFO: Processed SCB annotation: 3004236.txt
# INFO: Processed SCB annotation: 1395004.txt
# INFO: Processed SCB annotation: 0025015.txt
# INFO: Processed SCB annotation: 1292006.txt
# INFO: Processed SCB annotation: 3005101.txt
# INFO: Processed SCB annotation: 60_001551.txt
# INFO: Processed SCB annotation: 3003014.txt
# INFO: Processed SCB annotation: 20_001087.txt
# INFO: Processed SCB annotation: 134_000341.txt
# INFO: Processed SCB annotation: 2109024.txt
# INFO: Processed SCB annotation: 1255022.txt
# INFO: Processed SCB annotation: 0087_001219.txt
# INFO: Processed SCB annotation: 131_001520.txt
# INFO: Processed SCB annotation: 1314046.txt
# INFO: Processed SCB annotation: 1329006.txt
# INFO: Processed SCB annotation: 133_001129.txt
# INFO: Processed SCB annotation: 57_002277.txt
# INFO: Processed SCB annotation: 22_000772.txt
# INFO: Processed SCB annotation: 1262002.txt
# INFO: Processed SCB annotation: 60_001466.txt
# INFO: Processed SCB annotation: 0800036.txt
# INFO: Processed SCB annotation: 06000069.txt
# INFO: Processed SCB annotation: 1256030.txt
# INFO: Processed SCB annotation: 19_001356.txt
# INFO: Processed SCB annotation: 1294021.txt
# INFO: Processed SCB annotation: 0020001.txt
# INFO: Processed SCB annotation: 1332012.txt
# INFO: Processed SCB annotation: 1358010.txt
# INFO: Processed SCB annotation: 1262017.txt
# INFO: Processed SCB annotation: 3005071.txt
# INFO: Processed SCB annotation: 0089_001933.txt
# INFO: Processed SCB annotation: 0015008.txt
# INFO: Processed SCB annotation: 13160012.txt
# INFO: Processed SCB annotation: 3005086.txt
# INFO: Processed SCB annotation: 3004078.txt
# INFO: Processed SCB annotation: 06000088.txt
# INFO: Processed SCB annotation: 1262018.txt
# INFO: Processed SCB annotation: 55_001576.txt
# INFO: Processed SCB annotation: 130_001214.txt
# INFO: Processed SCB annotation: 1298009.txt
# INFO: Processed SCB annotation: 0401068.txt
# INFO: Processed SCB annotation: 11_001315.txt
# INFO: Processed SCB annotation: 0009008.txt
# INFO: Processed SCB annotation: 16_000745.txt
# INFO: Processed SCB annotation: 0013009.txt
# INFO: Processed SCB annotation: 1314054.txt
# INFO: Processed SCB annotation: 2110034.txt
# INFO: Processed SCB annotation: 0081_001482.txt
# INFO: Processed SCB annotation: 06010024.txt
# INFO: Processed SCB annotation: 1252001.txt
# INFO: Processed SCB annotation: 57_000441.txt
# INFO: Processed SCB annotation: 1283037.txt
# INFO: Processed SCB annotation: 3005143.txt
# INFO: Processed SCB annotation: 57_002269.txt
# INFO: Processed SCB annotation: 1363033.txt
# INFO: Processed SCB annotation: 3004101.txt
# INFO: Processed SCB annotation: 3000109.txt
# INFO: Processed SCB annotation: 17_001313.txt
# INFO: Processed SCB annotation: 1267010.txt
# INFO: Processed SCB annotation: 8_000789.txt
# INFO: Processed SCB annotation: 1290008.txt
# INFO: Processed SCB annotation: 0100073.txt
# INFO: Processed SCB annotation: 3003017.txt
# INFO: Processed SCB annotation: 60_001461.txt
# INFO: Processed SCB annotation: 3004033.txt
# INFO: Processed SCB annotation: 3005068.txt
# INFO: Processed SCB annotation: 1297006.txt
# INFO: Processed SCB annotation: 0106031.txt
# INFO: Processed SCB annotation: 1274051.txt
# INFO: Processed SCB annotation: 0088_001066.txt
# INFO: Processed SCB annotation: 0088_000435.txt
# INFO: Processed SCB annotation: 1265003.txt
# INFO: Processed SCB annotation: 1332047.txt
# INFO: Processed SCB annotation: 11_000057.txt
# INFO: Processed SCB annotation: 1128013.txt
# INFO: Processed SCB annotation: 18_002303.txt
# INFO: Processed SCB annotation: 1121002.txt
# INFO: Processed SCB annotation: 0081_000417.txt
# INFO: Processed SCB annotation: 1320031.txt
# INFO: Processed SCB annotation: 1313018.txt
# INFO: Processed SCB annotation: 16_002168.txt
# INFO: Processed SCB annotation: 06000002.txt
# INFO: Processed SCB annotation: 1305005.txt
# INFO: Processed SCB annotation: 18_001735.txt
# INFO: Processed SCB annotation: 1252006.txt
# INFO: Processed SCB annotation: 3005029.txt
# INFO: Processed SCB annotation: 1267017.txt
# INFO: Processed SCB annotation: 3004096.txt
# INFO: Processed SCB annotation: 1292001.txt
# INFO: Processed SCB annotation: 130_001631.txt
# INFO: Processed SCB annotation: 1267037.txt
# INFO: Processed SCB annotation: 3004099.txt
# INFO: Processed SCB annotation: 1429027.txt
# INFO: Processed SCB annotation: 16_002272.txt
# INFO: Processed SCB annotation: 0089_001166.txt
# INFO: Processed SCB annotation: 0089_000911.txt
# INFO: Processed SCB annotation: 3004072.txt
# INFO: Processed SCB annotation: 3005110.txt
# INFO: Processed SCB annotation: 17_001347.txt
# INFO: Processed SCB annotation: 1319031.txt
# INFO: Processed SCB annotation: 1249041.txt
# INFO: Processed SCB annotation: 1270008.txt
# INFO: Processed SCB annotation: 0101002.txt
# INFO: Processed SCB annotation: 0009047.txt
# INFO: Processed SCB annotation: 1130015.txt
# INFO: Processed SCB annotation: 3005187.txt
# INFO: Processed SCB annotation: 19_001397.txt
# INFO: Processed SCB annotation: 3004084.txt
# INFO: Processed SCB annotation: 3003111.txt
# INFO: Processed SCB annotation: 3004037.txt
# INFO: Processed SCB annotation: 1253045.txt
# INFO: Processed SCB annotation: 0086_002184.txt
# INFO: Processed SCB annotation: 1302016.txt
# INFO: Processed SCB annotation: 0006007.txt
# INFO: Processed SCB annotation: 1246027.txt
# INFO: Processed SCB annotation: 1319020.txt
# INFO: Processed SCB annotation: 1303009.txt
# INFO: Processed SCB annotation: 18_002379.txt
# INFO: Processed SCB annotation: 1395017.txt
# INFO: Processed SCB annotation: 20_001097.txt
# INFO: Processed SCB annotation: 0089_000097.txt
# INFO: Processed SCB annotation: 3005102.txt
# INFO: Processed SCB annotation: 1298006.txt
# INFO: Processed SCB annotation: 1303012.txt
# INFO: Processed SCB annotation: 130_001977.txt
# INFO: Processed SCB annotation: 55_001874.txt
# INFO: Processed SCB annotation: 1314013.txt
# INFO: Processed SCB annotation: 60_001204.txt
# INFO: Processed SCB annotation: 0025012.txt
# INFO: Processed SCB annotation: 0016030.txt
# INFO: Processed SCB annotation: 0081_001481.txt
# INFO: Processed SCB annotation: 0105033.txt
# INFO: Processed SCB annotation: 1295004.txt
# INFO: Processed SCB annotation: 1319007.txt
# INFO: Processed SCB annotation: 8_001989.txt
# INFO: Processed SCB annotation: 8_001403.txt
# INFO: Processed SCB annotation: 0086_002298.txt
# INFO: Processed SCB annotation: 1249007.txt
# INFO: Processed SCB annotation: 1292016.txt
# INFO: Processed SCB annotation: 1265082.txt
# INFO: Processed SCB annotation: 1120041.txt
# INFO: Processed SCB annotation: 1429016.txt
# INFO: Processed SCB annotation: 1301019.txt
# INFO: Processed SCB annotation: 19_001385.txt
# INFO: Processed SCB annotation: 0107037.txt
# INFO: Processed SCB annotation: 1340019.txt
# INFO: Processed SCB annotation: 1281020.txt
# INFO: Processed SCB annotation: 0086_000844.txt
# INFO: Processed SCB annotation: 0800041.txt
# INFO: Processed SCB annotation: 0011007.txt
# INFO: Processed SCB annotation: 1128009.txt
# INFO: Processed SCB annotation: 8_001599.txt
# INFO: Processed SCB annotation: 0089_001968.txt
# INFO: Processed SCB annotation: 1120062.txt
# INFO: Processed SCB annotation: 1281015.txt
# INFO: Processed SCB annotation: 1298044.txt
# INFO: Processed SCB annotation: 1128007.txt
# INFO: Processed SCB annotation: 0087_000207.txt
# INFO: Processed SCB annotation: 57_002210.txt
# INFO: Processed SCB annotation: 57_002385.txt
# INFO: Processed SCB annotation: 1265043.txt
# INFO: Processed SCB annotation: 1298018.txt
# INFO: Processed SCB annotation: 1333035.txt
# INFO: Processed SCB annotation: 0089_001790.txt
# INFO: Processed SCB annotation: 3004067.txt
# INFO: Processed SCB annotation: 1322005.txt
# INFO: Processed SCB annotation: 3000175.txt
# INFO: Processed SCB annotation: 1319025.txt
# INFO: Processed SCB annotation: 3004168.txt
# INFO: Processed SCB annotation: 0011026.txt
# INFO: Processed SCB annotation: 3004066.txt
# INFO: Processed SCB annotation: 57_002202.txt
# INFO: Processed SCB annotation: 1130022.txt
# INFO: Processed SCB annotation: 0800031.txt
# INFO: Processed SCB annotation: 19_000793.txt
# INFO: Processed SCB annotation: 1265039.txt
# INFO: Processed SCB annotation: 15_000419.txt
# INFO: Processed SCB annotation: 0400016.txt
# INFO: Processed SCB annotation: 133_001773.txt
# INFO: Processed SCB annotation: 0404040.txt
# INFO: Processed SCB annotation: 1311023.txt
# INFO: Processed SCB annotation: 18_000755.txt
# INFO: Processed SCB annotation: 1270042.txt
# INFO: Processed SCB annotation: 3004103.txt
# INFO: Processed SCB annotation: 3005106.txt
# INFO: Processed SCB annotation: 3000090.txt
# INFO: Processed SCB annotation: 57_001104.txt
# INFO: Processed SCB annotation: 0089_001666.txt
# INFO: Processed SCB annotation: 1120025.txt
# INFO: Processed SCB annotation: 8_001272.txt
# INFO: Processed SCB annotation: 1307033.txt
# INFO: Processed SCB annotation: 0016026.txt
# INFO: Processed SCB annotation: 0006001.txt
# INFO: Processed SCB annotation: 1270048.txt
# INFO: Processed SCB annotation: 3000050.txt
# INFO: Processed SCB annotation: 1424005.txt
# INFO: Processed SCB annotation: 1301021.txt
# INFO: Processed SCB annotation: 1266051.txt
# INFO: Processed SCB annotation: 60_001480.txt
# INFO: Processed SCB annotation: 20_001784.txt
# INFO: Processed SCB annotation: 1320014.txt
# INFO: Processed SCB annotation: 1298055.txt
# INFO: Processed SCB annotation: 1313040.txt
# INFO: Processed SCB annotation: 0024029.txt
# INFO: Processed SCB annotation: 1246022.txt
# INFO: Processed SCB annotation: 1304019.txt
# INFO: Processed SCB annotation: 12_002189.txt
# INFO: Processed SCB annotation: 0203022.txt
# INFO: Processed SCB annotation: 60_000990.txt
# INFO: Processed SCB annotation: 0091_002113.txt
# INFO: Processed SCB annotation: 18_001050.txt
# INFO: Processed SCB annotation: 3005139.txt
# INFO: Processed SCB annotation: 1309030.txt
# INFO: Processed SCB annotation: 15_001586.txt
# INFO: Processed SCB annotation: 0107003.txt
# INFO: Processed SCB annotation: 0081_000373.txt
# INFO: Processed SCB annotation: 3005142.txt
# INFO: Processed SCB annotation: 1265038.txt
# INFO: Processed SCB annotation: 1314039.txt
# INFO: Processed SCB annotation: 0089_001650.txt
# INFO: Processed SCB annotation: 0089_000862.txt
# INFO: Processed SCB annotation: 3003118.txt
# INFO: Processed SCB annotation: 3004013.txt
# INFO: Processed SCB annotation: 0101067.txt
# INFO: Processed SCB annotation: 1253079.txt
# INFO: Processed SCB annotation: 0403006.txt
# INFO: Processed SCB annotation: 1307021.txt
# INFO: Processed SCB annotation: 1256040.txt
# INFO: Processed SCB annotation: 0081_001804.txt
# INFO: Processed SCB annotation: 13160034.txt
# INFO: Processed SCB annotation: 1121035.txt
# INFO: Processed SCB annotation: 0403016.txt
# INFO: Processed SCB annotation: 3004182.txt
# INFO: Processed SCB annotation: 1121021.txt
# INFO: Processed SCB annotation: 1304005.txt
# INFO: Processed SCB annotation: 1298056.txt
# INFO: Processed SCB annotation: 57_002211.txt
# INFO: Processed SCB annotation: 1395019.txt
# INFO: Processed SCB annotation: 131_001153.txt
# INFO: Processed SCB annotation: 3005026.txt
# INFO: Processed SCB annotation: 0006008.txt
# INFO: Processed SCB annotation: 1266060.txt
# INFO: Processed SCB annotation: 1266039.txt
# INFO: Processed SCB annotation: 57_002271.txt
# INFO: Processed SCB annotation: 0089_000407.txt
# INFO: Processed SCB annotation: 0016025.txt
# INFO: Processed SCB annotation: 1319035.txt
# INFO: Processed SCB annotation: 0105018.txt
# INFO: Processed SCB annotation: 1431013.txt
# INFO: Processed SCB annotation: 8_000402.txt
# INFO: Processed SCB annotation: 0101072.txt
# INFO: Processed SCB annotation: 3000124.txt
# INFO: Processed SCB annotation: 1270078.txt
# INFO: Processed SCB annotation: 12_001365.txt
# INFO: Processed SCB annotation: 3000111.txt
# INFO: Processed SCB annotation: 0404047.txt
# INFO: Processed SCB annotation: 0089_001640.txt
# INFO: Processed SCB annotation: 133_001002.txt
# INFO: Processed SCB annotation: 130_000666.txt
# INFO: Processed SCB annotation: 1298017.txt
# INFO: Processed SCB annotation: 3000003.txt
# INFO: Processed SCB annotation: 1270013.txt
# INFO: Processed SCB annotation: 3005292.txt
# INFO: Processed SCB annotation: 4_001467.txt
# INFO: Processed SCB annotation: 4_002262.txt
# INFO: Processed SCB annotation: 18_000192.txt
# INFO: Processed SCB annotation: 11_001059.txt
# INFO: Processed SCB annotation: 0100056.txt
# INFO: Processed SCB annotation: 0087_000206.txt
# INFO: Processed SCB annotation: 3005056.txt
# INFO: Processed SCB annotation: 16_000894.txt
# INFO: Processed SCB annotation: 1399023.txt
# INFO: Processed SCB annotation: 0100029.txt
# INFO: Processed SCB annotation: 2110035.txt
# INFO: Processed SCB annotation: 1303033.txt
# INFO: Processed SCB annotation: 15_001501.txt
# INFO: Processed SCB annotation: 1320026.txt
# INFO: Processed SCB annotation: 1267086.txt
# INFO: Processed SCB annotation: 1255012.txt
# INFO: Processed SCB annotation: 55_000716.txt
# INFO: Processed SCB annotation: 1257002.txt
# INFO: Processed SCB annotation: 0081_000377.txt
# INFO: Processed SCB annotation: 0006017.txt
# INFO: Processed SCB annotation: 0401006.txt
# INFO: Processed SCB annotation: 0081_000419.txt
# INFO: Processed SCB annotation: 0006018.txt
# INFO: Processed SCB annotation: 133_001637.txt
# INFO: Processed SCB annotation: 0100076.txt
# INFO: Processed SCB annotation: 1257007.txt
# INFO: Processed SCB annotation: 15_001875.txt
# INFO: Processed SCB annotation: 3004127.txt
# INFO: Processed SCB annotation: 0205006.txt
# INFO: Processed SCB annotation: 3000135.txt
# INFO: Processed SCB annotation: 9_000839.txt
# INFO: Processed SCB annotation: 0086_001186.txt
# INFO: Processed SCB annotation: 0081_000454.txt
# INFO: Processed SCB annotation: 16_000836.txt
# INFO: Processed SCB annotation: 130_001708.txt
# INFO: Processed SCB annotation: 3000019.txt
# INFO: Processed SCB annotation: 3005234.txt
# INFO: Processed SCB annotation: 130_000970.txt
# INFO: Processed SCB annotation: 1322027.txt
# INFO: Processed SCB annotation: 06000023.txt
# INFO: Processed SCB annotation: 131_000259.txt
# INFO: Processed SCB annotation: 57_002223.txt
# INFO: Processed SCB annotation: 3004090.txt
# INFO: Processed SCB annotation: 57_002212.txt
# INFO: Processed SCB annotation: 0086_002276.txt
# INFO: Processed SCB annotation: 0009003.txt
# INFO: Processed SCB annotation: 0086_000249.txt
# INFO: Processed SCB annotation: 1253020.txt
# INFO: Processed SCB annotation: 3004073.txt
# INFO: Processed SCB annotation: 2_000110.txt
# INFO: Processed SCB annotation: 0081_001502.txt
# INFO: Processed SCB annotation: 0081_001794.txt
# INFO: Processed SCB annotation: 1395006.txt
# INFO: Processed SCB annotation: 19_001951.txt
# INFO: Processed SCB annotation: 0087_000290.txt
# INFO: Processed SCB annotation: 0011013.txt
# INFO: Processed SCB annotation: 1319027.txt
# INFO: Processed SCB annotation: 60_001539.txt
# INFO: Processed SCB annotation: 1266054.txt
# INFO: Processed SCB annotation: 0102025.txt
# INFO: Processed SCB annotation: 0088_001065.txt
# INFO: Processed SCB annotation: 3003068.txt
# INFO: Processed SCB annotation: 1314056.txt
# INFO: Processed SCB annotation: 1265006.txt
# INFO: Processed SCB annotation: 0088_001972.txt
# INFO: Processed SCB annotation: 3004185.txt
# INFO: Processed SCB annotation: 18_000121.txt
# INFO: Processed SCB annotation: 12_002597.txt
# INFO: Processed SCB annotation: 1329016.txt
# INFO: Processed SCB annotation: 3005040.txt
# INFO: Processed SCB annotation: 3003147.txt
# INFO: Processed SCB annotation: 57_002274.txt
# INFO: Processed SCB annotation: 60_001643.txt
# INFO: Processed SCB annotation: 1307047.txt
# INFO: Processed SCB annotation: 0401043.txt
# INFO: Processed SCB annotation: 1128015.txt
# INFO: Processed SCB annotation: 0089_001808.txt
# INFO: Processed SCB annotation: 0089_000201.txt
# INFO: Processed SCB annotation: 0011016.txt
# INFO: Processed SCB annotation: 3003096.txt
# INFO: Processed SCB annotation: 3004081.txt
# INFO: Processed SCB annotation: 11_000887.txt
# INFO: Processed SCB annotation: 3005197.txt
# INFO: Processed SCB annotation: 3005169.txt
# INFO: Processed SCB annotation: 1309002.txt
# INFO: Processed SCB annotation: 1295011.txt
# INFO: Processed SCB annotation: 3004202.txt
# INFO: Processed SCB annotation: 0403020.txt
# INFO: Processed SCB annotation: 0081_000425.txt
# INFO: Processed SCB annotation: 1270069.txt
# INFO: Processed SCB annotation: 1270035.txt
# INFO: Processed SCB annotation: 130_000264.txt
# INFO: Processed SCB annotation: 18_002047.txt
# INFO: Processed SCB annotation: 1431009.txt
# INFO: Processed SCB annotation: 0102043.txt
# INFO: Processed SCB annotation: 0101005.txt
# INFO: Processed SCB annotation: 0106005.txt
# INFO: Processed SCB annotation: 18_001772.txt
# INFO: Processed SCB annotation: 57_002276.txt
# INFO: Processed SCB annotation: 1358004.txt
# INFO: Processed SCB annotation: 138_002648.txt
# INFO: Processed SCB annotation: 0091_001666.txt
# INFO: Processed SCB annotation: 3000009.txt
# INFO: Processed SCB annotation: 1253060.txt
# INFO: Processed SCB annotation: 3005117.txt
# INFO: Processed SCB annotation: 55_001087.txt
# INFO: Processed SCB annotation: 0800030.txt
# INFO: Processed SCB annotation: 1307018.txt
# INFO: Processed SCB annotation: 0086_000616.txt
# INFO: Processed SCB annotation: 1330034.txt
# INFO: Processed SCB annotation: 1130005.txt
# INFO: Processed SCB annotation: 1265084.txt
# INFO: Processed SCB annotation: 1292011.txt
# INFO: Processed SCB annotation: 0105038.txt
# INFO: Processed SCB annotation: 0089_001750.txt
# INFO: Processed SCB annotation: 1265063.txt
# INFO: Processed SCB annotation: 16_000737.txt
# INFO: Processed SCB annotation: 1329022.txt
# INFO: Processed SCB annotation: 18_000584.txt
# INFO: Processed SCB annotation: 0401056.txt
# INFO: Processed SCB annotation: 1255004.txt
# INFO: Processed SCB annotation: 1249015.txt
# INFO: Processed SCB annotation: 57_000205.txt
# INFO: Processed SCB annotation: 15_001884.txt
# INFO: Processed SCB annotation: 1313030.txt
# INFO: Processed SCB annotation: 1121012.txt
# INFO: Processed SCB annotation: 3003034.txt
# INFO: Processed SCB annotation: 1319026.txt
# INFO: Processed SCB annotation: 1270066.txt
# INFO: Processed SCB annotation: 0089_001776.txt
# INFO: Processed SCB annotation: 0091_001452.txt
# INFO: Processed SCB annotation: 11_001048.txt
# INFO: Processed SCB annotation: 06010001.txt
# INFO: Processed SCB annotation: 3000085.txt
# INFO: Processed SCB annotation: 3000246.txt
# INFO: Processed SCB annotation: 0800013.txt
# INFO: Processed SCB annotation: 1000015.txt
# INFO: Processed SCB annotation: 60_001535.txt
# INFO: Processed SCB annotation: 1257051.txt
# INFO: Processed SCB annotation: 1333010.txt
# INFO: Processed SCB annotation: 18_000548.txt
# INFO: Processed SCB annotation: 1333007.txt
# INFO: Processed SCB annotation: 1266033.txt
# INFO: Processed SCB annotation: 3003032.txt
# INFO: Processed SCB annotation: 11_001909.txt
# INFO: Processed SCB annotation: 1295006.txt
# INFO: Processed SCB annotation: 1270079.txt
# INFO: Processed SCB annotation: 1267122.txt
# INFO: Processed SCB annotation: 1246026.txt
# INFO: Processed SCB annotation: 1256016.txt
# INFO: Processed SCB annotation: 1265073.txt
# INFO: Processed SCB annotation: 60_001747.txt
# INFO: Processed SCB annotation: 1317028.txt
# INFO: Processed SCB annotation: 57_001631.txt
# INFO: Processed SCB annotation: 0101049.txt
# INFO: Processed SCB annotation: 0101045.txt
# INFO: Processed SCB annotation: 1333043.txt
# INFO: Processed SCB annotation: 12_002139.txt
# INFO: Processed SCB annotation: 1252019.txt
# INFO: Processed SCB annotation: 130_001909.txt
# INFO: Processed SCB annotation: 8_001619.txt
# INFO: Processed SCB annotation: 1270014.txt
# INFO: Processed SCB annotation: 1266046.txt
# INFO: Processed SCB annotation: 0404007.txt
# INFO: Processed SCB annotation: 1340003.txt
# INFO: Processed SCB annotation: 0400019.txt
# INFO: Processed SCB annotation: 1317001.txt
# INFO: Processed SCB annotation: 3005282.txt
# INFO: Processed SCB annotation: 3005254.txt
# INFO: Processed SCB annotation: 1246023.txt
# INFO: Processed SCB annotation: 1332038.txt
# INFO: Processed SCB annotation: 57_002199.txt
# INFO: Processed SCB annotation: 130_001987.txt
# INFO: Processed SCB annotation: 0100032.txt
# INFO: Processed SCB annotation: 1329025.txt
# INFO: Processed SCB annotation: 0100060.txt
# INFO: Processed SCB annotation: 1307014.txt
# INFO: Processed SCB annotation: 1429042.txt
# INFO: Processed SCB annotation: 0800038.txt
# INFO: Processed SCB annotation: 1329007.txt
# INFO: Processed SCB annotation: 1267131.txt
# INFO: Processed SCB annotation: 57_002231.txt
# INFO: Processed SCB annotation: 18_001705.txt
# INFO: Processed SCB annotation: 15_000429.txt
# INFO: Processed SCB annotation: 1331006.txt
# INFO: Processed SCB annotation: 1431008.txt
# INFO: Processed SCB annotation: 13160015.txt
# INFO: Processed SCB annotation: 60_001496.txt
# INFO: Processed SCB annotation: 60_001474.txt
# INFO: Processed SCB annotation: 0201005.txt
# INFO: Processed SCB annotation: 1120022.txt
# INFO: Processed SCB annotation: 1130011.txt
# INFO: Processed SCB annotation: 1298019.txt
# INFO: Processed SCB annotation: 1128012.txt
# INFO: Processed SCB annotation: 0086_002313.txt
# INFO: Processed SCB annotation: 3005028.txt
# INFO: Processed SCB annotation: 0401031.txt
# INFO: Processed SCB annotation: 3000062.txt
# INFO: Processed SCB annotation: 1257028.txt
# INFO: Processed SCB annotation: 17_000754.txt
# INFO: Processed SCB annotation: 8_001421.txt
# INFO: Processed SCB annotation: 1265019.txt
# INFO: Processed SCB annotation: 0016015.txt
# INFO: Processed SCB annotation: 0404005.txt
# INFO: Processed SCB annotation: 1424015.txt
# INFO: Processed SCB annotation: 1322012.txt
# INFO: Processed SCB annotation: 3003021.txt
# INFO: Processed SCB annotation: 130_001952.txt
# INFO: Processed SCB annotation: 1399018.txt
# INFO: Processed SCB annotation: 0102027.txt
# INFO: Processed SCB annotation: 1274047.txt
# INFO: Processed SCB annotation: 0107034.txt
# INFO: Processed SCB annotation: 16_001709.txt
# INFO: Processed SCB annotation: 0024021.txt
# INFO: Processed SCB annotation: 57_001102.txt
# INFO: Processed SCB annotation: 1424016.txt
# INFO: Processed SCB annotation: 16_001272.txt
# INFO: Processed SCB annotation: 3000250.txt
# INFO: Processed SCB annotation: 1262009.txt
# INFO: Processed SCB annotation: 1307043.txt
# INFO: Processed SCB annotation: 0404003.txt
# INFO: Processed SCB annotation: 0013013.txt
# INFO: Processed SCB annotation: 1243027.txt
# INFO: Processed SCB annotation: 1319012.txt
# INFO: Processed SCB annotation: 0081_000426.txt
# INFO: Processed SCB annotation: 1256038.txt
# INFO: Processed SCB annotation: 1399017.txt
# INFO: Processed SCB annotation: 0081_001802.txt
# INFO: Processed SCB annotation: 3005246.txt
# INFO: Processed SCB annotation: 1317007.txt
# INFO: Processed SCB annotation: 1429005.txt
# INFO: Processed SCB annotation: 0201015.txt
# INFO: Processed SCB annotation: 1252018.txt
# INFO: Processed SCB annotation: 0025021.txt
# INFO: Processed SCB annotation: 2109020.txt
# INFO: Processed SCB annotation: 1128040.txt
# INFO: Processed SCB annotation: 13160039.txt
# INFO: Processed SCB annotation: 20_001029.txt
# INFO: Processed SCB annotation: 1130043.txt
# INFO: Processed SCB annotation: 1329005.txt
# INFO: Processed SCB annotation: 1304017.txt
# INFO: Processed SCB annotation: 1317031.txt
# INFO: Processed SCB annotation: 3000066.txt
# INFO: Processed SCB annotation: 0203011.txt
# INFO: Processed SCB annotation: 0086_000617.txt
# INFO: Processed SCB annotation: 4_001388.txt
# INFO: Processed SCB annotation: 9_001632.txt
# INFO: Processed SCB annotation: 3005258.txt
# INFO: Processed SCB annotation: 0105010.txt
# INFO: Processed SCB annotation: 3004119.txt
# INFO: Processed SCB annotation: 0086_000250.txt
# INFO: Processed SCB annotation: 0100078.txt
# INFO: Processed SCB annotation: 0404017.txt
# INFO: Processed SCB annotation: 19_002436.txt
# INFO: Processed SCB annotation: 133_001768.txt
# INFO: Processed SCB annotation: 06000004.txt
# INFO: Processed SCB annotation: 60_001458.txt
# INFO: Processed SCB annotation: 130_002015.txt
# INFO: Processed SCB annotation: 0081_001501.txt
# INFO: Processed SCB annotation: 1322031.txt
# INFO: Processed SCB annotation: 06000014.txt
# INFO: Processed SCB annotation: 16_000918.txt
# INFO: Processed SCB annotation: 60_001537.txt
# INFO: Processed SCB annotation: 0089_001714.txt
# INFO: Processed SCB annotation: 57_002268.txt
# INFO: Processed SCB annotation: 1295015.txt
# INFO: Processed SCB annotation: 0106024.txt
# INFO: Processed SCB annotation: 3005051.txt
# INFO: Processed SCB annotation: 0089_001643.txt
# INFO: Processed SCB annotation: 1295003.txt
# INFO: Processed SCB annotation: 1265044.txt
# INFO: Processed SCB annotation: 1267128.txt
# INFO: Processed SCB annotation: 1301020.txt
# INFO: Processed SCB annotation: 0087_000125.txt
# INFO: Processed SCB annotation: 60_001573.txt
# INFO: Processed SCB annotation: 1424037.txt
# INFO: Processed SCB annotation: 1302020.txt
# INFO: Processed SCB annotation: 0013004.txt
# INFO: Processed SCB annotation: 0404035.txt
# INFO: Processed SCB annotation: 1424004.txt
# INFO: Processed SCB annotation: 3003046.txt
# INFO: Processed SCB annotation: 1120031.txt
# INFO: Processed SCB annotation: 3005296.txt
# INFO: Processed SCB annotation: 3000202.txt
# INFO: Processed SCB annotation: 1363029.txt
# INFO: Processed SCB annotation: 0087_001916.txt
# INFO: Processed SCB annotation: 3004137.txt
# INFO: Processed SCB annotation: 1120027.txt
# INFO: Processed SCB annotation: 0107017.txt
# INFO: Processed SCB annotation: 1246045.txt
# INFO: Processed SCB annotation: 0202005.txt
# INFO: Processed SCB annotation: 1429015.txt
# INFO: Processed SCB annotation: 3005247.txt
# INFO: Processed SCB annotation: 55_002029.txt
# INFO: Processed SCB annotation: 0089_001798.txt
# INFO: Processed SCB annotation: 1290019.txt
# INFO: Processed SCB annotation: 1367018.txt
# INFO: Processed SCB annotation: 1130031.txt
# INFO: Processed SCB annotation: 15_002006.txt
# INFO: Processed SCB annotation: 1270054.txt
# INFO: Processed SCB annotation: 9_000443.txt
# INFO: Processed SCB annotation: 3005195.txt
# INFO: Processed SCB annotation: 1266037.txt
# INFO: Processed SCB annotation: 0089_001598.txt
# INFO: Processed SCB annotation: 1313028.txt
# INFO: Processed SCB annotation: 57_001684.txt
# INFO: Processed SCB annotation: 1320016.txt
# INFO: Processed SCB annotation: 3003108.txt
# INFO: Processed SCB annotation: 0009035.txt
# INFO: Processed SCB annotation: 0088_000413.txt
# INFO: Processed SCB annotation: 0025025.txt
# INFO: Processed SCB annotation: 3003048.txt
# INFO: Processed SCB annotation: 3003040.txt
# INFO: Processed SCB annotation: 3003013.txt
# INFO: Processed SCB annotation: 3005237.txt
# INFO: Processed SCB annotation: 1290003.txt
# INFO: Processed SCB annotation: 1302017.txt
# INFO: Processed SCB annotation: 18_001928.txt
# INFO: Processed SCB annotation: 17_000997.txt
# INFO: Processed SCB annotation: 0091_000920.txt
# INFO: Processed SCB annotation: 21_000403.txt
# INFO: Processed SCB annotation: 0404019.txt
# INFO: Processed SCB annotation: 1314026.txt
# INFO: Processed SCB annotation: 3005160.txt
# INFO: Processed SCB annotation: 0086_002301.txt
# INFO: Processed SCB annotation: 60_001668.txt
# INFO: Processed SCB annotation: 4_002074.txt
# INFO: Processed SCB annotation: 1265057.txt
# INFO: Processed SCB annotation: 0089_000925.txt
# INFO: Processed SCB annotation: 134_001862.txt
# INFO: Processed SCB annotation: 1307051.txt
# INFO: Processed SCB annotation: 1265102.txt
# INFO: Processed SCB annotation: 0081_000378.txt
# INFO: Processed SCB annotation: 16_000896.txt
# INFO: Processed SCB annotation: 0011033.txt
# INFO: Processed SCB annotation: 133_000524.txt
# INFO: Processed SCB annotation: 1267071.txt
# INFO: Processed SCB annotation: 0006019.txt
# INFO: Processed SCB annotation: 0100034.txt
# INFO: Processed SCB annotation: 3004126.txt
# INFO: Processed SCB annotation: 0011030.txt
# INFO: Processed SCB annotation: 1303019.txt
# INFO: Processed SCB annotation: 1270005.txt
# INFO: Processed SCB annotation: 0404033.txt
# INFO: Processed SCB annotation: 1121023.txt
# INFO: Processed SCB annotation: 20_000769.txt
# INFO: Processed SCB annotation: 1320021.txt
# INFO: Processed SCB annotation: 1128019.txt
# INFO: Processed SCB annotation: 17_001296.txt
# INFO: Processed SCB annotation: 0102029.txt
# INFO: Processed SCB annotation: 3004161.txt
# INFO: Processed SCB annotation: 0091_001181.txt
# INFO: Processed SCB annotation: 1267059.txt
# INFO: Processed SCB annotation: 1121004.txt
# INFO: Processed SCB annotation: 1304014.txt
# INFO: Processed SCB annotation: 0086_000619.txt
# INFO: Processed SCB annotation: 0086_002401.txt
# INFO: Processed SCB annotation: 1257010.txt
# ...
# INFO: Processed SCB annotation: 18_000511.txt
# INFO: Processed SCB annotation: 60_001744.txt
# INFO: Processed SCB annotation: 0081_000365.txt
# INFO: Processed SCB annotation: 3005063.txt
# INFO: Processed SCB annotation: 0404034.txt
# INFO: Processed SCB annotation: 0081_001791.txt
# INFO: Processed SCB annotation: 1256009.txt
# INFO: Processed SCB annotation: 0086_002316.txt
# INFO: Processed SCB annotation: 0002056.txt
# INFO: Processed SCB annotation: 18_000474.txt
# INFO: Processed SCB annotation: 0014018.txt
# INFO: Processed SCB annotation: 1331038.txt
# INFO: Processed SCB annotation: 10_001747.txt
# INFO: Processed SCB annotation: 1270061.txt
# INFO: Processed SCB annotation: 8_002190.txt
# INFO: Processed SCB annotation: 10_001550.txt
# INFO: Processed SCB annotation: 0401013.txt
# INFO: Processed SCB annotation: 0101033.txt
# INFO: Processed SCB annotation: 3003016.txt
# INFO: Processed SCB annotation: 1313011.txt
# INFO: Processed SCB annotation: 1331042.txt
# INFO: Processed SCB annotation: 1330041.txt
# INFO: Processed SCB annotation: 8_001158.txt
# INFO: Processed SCB annotation: 15_002032.txt
# INFO: Processed SCB annotation: 3005194.txt
# INFO: Processed SCB annotation: 0086_002336.txt
# INFO: Processed SCB annotation: 0081_001867.txt
# INFO: Processed SCB annotation: 0203017.txt
# INFO: Processed SCB annotation: 0008012.txt
# INFO: Processed SCB annotation: 3004190.txt
# INFO: Processed SCB annotation: 57_000624.txt
# INFO: Processed SCB annotation: 10_002141.txt
# INFO: Processed SCB annotation: 133_001722.txt
# INFO: Processed SCB annotation: 13160047.txt
# INFO: Processed SCB annotation: 0006005.txt
# INFO: Processed SCB annotation: 3005144.txt
# INFO: Processed SCB annotation: 1395012.txt
# INFO: Processed SCB annotation: 0400015.txt
# INFO: Processed SCB annotation: 20_001106.txt
# INFO: Processed SCB annotation: 3000030.txt
# INFO: Processed SCB annotation: 0403032.txt
# INFO: Processed SCB annotation: 60_001512.txt
# INFO: Processed SCB annotation: 130_000903.txt
# INFO: Processed SCB annotation: 1431002.txt
# INFO: Processed SCB annotation: 0081_000214.txt
# INFO: Processed SCB annotation: 1313034.txt
# INFO: Processed SCB annotation: 0401003.txt
# INFO: Processed SCB annotation: 18_001321.txt
# INFO: Processed SCB annotation: 1243032.txt
# INFO: Processed SCB annotation: 3002123.txt
# INFO: Processed SCB annotation: 1318013.txt
# INFO: Processed SCB annotation: 0101043.txt
# INFO: Processed SCB annotation: 1292014.txt
# INFO: Processed SCB annotation: 0091_000183.txt
# INFO: Processed SCB annotation: 1333044.txt
# INFO: Processed SCB annotation: 1314048.txt
# INFO: Processed SCB annotation: 0008027.txt
# INFO: Processed SCB annotation: 1298049.txt
# INFO: Processed SCB annotation: 3005231.txt
# INFO: Processed SCB annotation: 3004118.txt
# INFO: Processed SCB annotation: 3003109.txt
# INFO: Processed SCB annotation: 0202014.txt
# INFO: Processed SCB annotation: 0102020.txt
# INFO: Processed SCB annotation: 1257015.txt
# INFO: Processed SCB annotation: 3001218.txt
# INFO: Processed SCB annotation: 1322039.txt
# INFO: Processed SCB annotation: 1305007.txt
# INFO: Processed SCB annotation: 1340014.txt
# INFO: Processed SCB annotation: 3001352.txt
# INFO: Processed SCB annotation: 1290009.txt
# INFO: Processed SCB annotation: 3001173.txt
# INFO: Processed SCB annotation: 0089_001630.txt
# INFO: Processed SCB annotation: 3003036.txt
# INFO: Processed SCB annotation: 0203016.txt
# INFO: Processed SCB annotation: 3005228.txt
# INFO: Processed SCB annotation: 0006014.txt
# INFO: Processed SCB annotation: 1283049.txt
# INFO: Processed SCB annotation: 0087_000929.txt
# INFO: Processed SCB annotation: 0100055.txt
# INFO: Processed SCB annotation: 0091_001499.txt
# INFO: Processed SCB annotation: 130_001954.txt
# INFO: Processed SCB annotation: 1249013.txt
# INFO: Processed SCB annotation: 1379038.txt
# INFO: Processed SCB annotation: 21_000976.txt
# INFO: Processed SCB annotation: 10_002638.txt
# INFO: Processed SCB annotation: 1257022.txt
# INFO: Processed SCB annotation: 0090_000398.txt
# INFO: Processed SCB annotation: 1431010.txt
# INFO: Processed SCB annotation: 0086_002321.txt
# INFO: Processed SCB annotation: 1309025.txt
# INFO: Processed SCB annotation: 1303013.txt
# INFO: Processed SCB annotation: 3001222.txt
# INFO: Processed SCB annotation: 1333022.txt
# INFO: Processed SCB annotation: 1249067.txt
# INFO: Processed SCB annotation: 18_000213.txt
# INFO: Processed SCB annotation: 0086_000652.txt
# INFO: Processed SCB annotation: 0089_001642.txt
# INFO: Processed SCB annotation: 3003084.txt
# INFO: Processed SCB annotation: 1120038.txt
# INFO: Processed SCB annotation: 0401034.txt
# INFO: Processed SCB annotation: 0013021.txt
# INFO: Processed SCB annotation: 19_000906.txt
# INFO: Processed SCB annotation: 3000203.txt
# INFO: Processed SCB annotation: 3000187.txt
# INFO: Processed SCB annotation: 2109005.txt
# INFO: Processed SCB annotation: 16_001908.txt
# INFO: Processed SCB annotation: 1256050.txt
# INFO: Processed SCB annotation: 21_002085.txt
# INFO: Processed SCB annotation: 1243011.txt
# INFO: Processed SCB annotation: 0104021.txt
# INFO: Processed SCB annotation: 1304018.txt
# INFO: Processed SCB annotation: 0400006.txt
# INFO: Processed SCB annotation: 3004054.txt
# INFO: Processed SCB annotation: 10_000695.txt
# INFO: Processed SCB annotation: 16_000726.txt
# INFO: Processed SCB annotation: 60_001465.txt
# INFO: Processed SCB annotation: 3000088.txt
# INFO: Processed SCB annotation: 1363002.txt
# INFO: Processed SCB annotation: 0101036.txt
# INFO: Processed SCB annotation: 1329003.txt
# INFO: Processed SCB annotation: 0100068.txt
# INFO: Processed SCB annotation: 18_001964.txt
# INFO: Processed SCB annotation: 0016028.txt
# INFO: Processed SCB annotation: 130_001624.txt
# INFO: Processed SCB annotation: 13160031.txt
# INFO: Processed SCB annotation: 06000018.txt
# INFO: Processed SCB annotation: 0089_001651.txt
# INFO: Processed SCB annotation: 3003148.txt
# INFO: Processed SCB annotation: 60_002035.txt
# INFO: Processed SCB annotation: 1000036.txt
# INFO: Processed SCB annotation: 20_001081.txt
# INFO: Processed SCB annotation: 10_002370.txt
# INFO: Processed SCB annotation: 1304038.txt
# INFO: Processed SCB annotation: 0101012.txt
# INFO: Processed SCB annotation: 20_000740.txt
# INFO: Processed SCB annotation: 1429003.txt
# INFO: Processed SCB annotation: 10_001806.txt
# INFO: Processed SCB annotation: 1395014.txt
# INFO: Processed SCB annotation: 0081_000458.txt
# INFO: Processed SCB annotation: 20_001075.txt
# INFO: Processed SCB annotation: 0101013.txt
# INFO: Processed SCB annotation: 1256046.txt
# INFO: Processed SCB annotation: 60_000836.txt
# INFO: Processed SCB annotation: 0086_000192.txt
# INFO: Processed SCB annotation: 130_001072.txt
# INFO: Processed SCB annotation: 10_000722.txt
# INFO: Processed SCB annotation: 1399009.txt
# INFO: Processed SCB annotation: 1325044.txt
# INFO: Processed SCB annotation: 16_000862.txt
# INFO: Processed SCB annotation: 10_002077.txt
# INFO: Processed SCB annotation: 0081_000383.txt
# INFO: Processed SCB annotation: 0016008.txt
# INFO: Processed SCB annotation: 3003126.txt
# INFO: Processed SCB annotation: 1320024.txt
# INFO: Processed SCB annotation: 19_001946.txt
# INFO: Processed SCB annotation: 0103013.txt
# INFO: Processed SCB annotation: 1265045.txt
# INFO: Processed SCB annotation: 130_000582.txt
# INFO: Processed SCB annotation: 0002047.txt
# INFO: Processed SCB annotation: 3005140.txt
# INFO: Processed SCB annotation: 0086_000280.txt
# INFO: Processed SCB annotation: 1000019.txt
# INFO: Processed SCB annotation: 1320028.txt
# INFO: Processed SCB annotation: 13160026.txt
# INFO: Processed SCB annotation: 11_000765.txt
# INFO: Processed SCB annotation: 1249048.txt
# INFO: Processed SCB annotation: 1358002.txt
# INFO: Processed SCB annotation: 1303032.txt
# INFO: Processed SCB annotation: 1302033.txt
# INFO: Processed SCB annotation: 6_002271.txt
# INFO: Processed SCB annotation: 18_002170.txt
# INFO: Processed SCB annotation: 1314044.txt
# INFO: Processed SCB annotation: 1307015.txt
# INFO: Processed SCB annotation: 1429038.txt
# INFO: Processed SCB annotation: 10_001810.txt
# INFO: Processed SCB annotation: 0107006.txt
# INFO: Processed SCB annotation: 0015003.txt
# INFO: Processed SCB annotation: 0403036.txt
# INFO: Processed SCB annotation: 0100082.txt
# INFO: Processed SCB annotation: 1265094.txt
# INFO: Processed SCB annotation: 0403041.txt
# INFO: Processed SCB annotation: 19_000472.txt
# INFO: Processed SCB annotation: 133_000918.txt
# INFO: Processed SCB annotation: 0101025.txt
# INFO: Processed SCB annotation: 0404046.txt
# INFO: Processed SCB annotation: 130_001111.txt
# INFO: Processed SCB annotation: 0025042.txt
# INFO: Processed SCB annotation: 0091_001345.txt
# INFO: Processed SCB annotation: 20_001764.txt
# INFO: Processed SCB annotation: 0091_001941.txt
# INFO: Processed SCB annotation: 1128038.txt
# INFO: Processed SCB annotation: 3001206.txt
# INFO: Processed SCB annotation: 1311012.txt
# INFO: Processed SCB annotation: 3001033.txt
# INFO: Processed SCB annotation: 0100025.txt
# INFO: Processed SCB annotation: 0100067.txt
# INFO: Processed SCB annotation: 3005159.txt
# INFO: Processed SCB annotation: 0400027.txt
# INFO: Processed SCB annotation: 1270100.txt
# INFO: Processed SCB annotation: 0403038.txt
# INFO: Processed SCB annotation: 57_002230.txt
# INFO: Processed SCB annotation: 1429029.txt
# INFO: Processed SCB annotation: 0087_001945.txt
# INFO: Processed SCB annotation: 0400004.txt
# INFO: Processed SCB annotation: 17_001091.txt
# INFO: Processed SCB annotation: 2110015.txt
# INFO: Processed SCB annotation: 1305011.txt
# INFO: Processed SCB annotation: 1309019.txt
# INFO: Processed SCB annotation: 0086_002230.txt
# INFO: Processed SCB annotation: 0800039.txt
# INFO: Processed SCB annotation: 1317027.txt
# INFO: Processed SCB annotation: 16_000913.txt
# INFO: Processed SCB annotation: 0103012.txt
# INFO: Processed SCB annotation: 0025004.txt
# INFO: Processed SCB annotation: 1281007.txt
# INFO: Processed SCB annotation: 1281041.txt
# INFO: Processed SCB annotation: 1265061.txt
# INFO: Processed SCB annotation: 0089_000521.txt
# INFO: Processed SCB annotation: 3005209.txt
# INFO: Processed SCB annotation: 0089_001645.txt
# INFO: Processed SCB annotation: 0088_001875.txt
# INFO: Processed SCB annotation: 1000008.txt
# INFO: Processed SCB annotation: 1395001.txt
# INFO: Processed SCB annotation: 3000218.txt
# INFO: Processed SCB annotation: 3005267.txt
# INFO: Processed SCB annotation: 3005053.txt
# INFO: Processed SCB annotation: 9_000142.txt
# INFO: Processed SCB annotation: 1322034.txt
# INFO: Processed SCB annotation: 3005008.txt
# INFO: Processed SCB annotation: 0089_001648.txt
# INFO: Processed SCB annotation: 1274013.txt
# INFO: Processed SCB annotation: 3004028.txt
# INFO: Processed SCB annotation: 21_000498.txt
# INFO: Processed SCB annotation: 1314019.txt
# INFO: Processed SCB annotation: 0404045.txt
# INFO: Processed SCB annotation: 1363005.txt
# INFO: Processed SCB annotation: 3002212.txt
# INFO: Processed SCB annotation: 3003063.txt
# INFO: Processed SCB annotation: 21_000389.txt
# INFO: Processed SCB annotation: 20_000881.txt
# INFO: Processed SCB annotation: 2_001703.txt
# INFO: Processed SCB annotation: 3000181.txt
# INFO: Processed SCB annotation: 0105008.txt
# INFO: Processed SCB annotation: 3005193.txt
# INFO: Processed SCB annotation: 16_001780.txt
# INFO: Processed SCB annotation: 3000116.txt
# INFO: Processed SCB annotation: 3003066.txt
# INFO: Processed SCB annotation: 0800006.txt
# INFO: Processed SCB annotation: 0108044.txt
# INFO: Processed SCB annotation: 1265081.txt
# INFO: Processed SCB annotation: 1283007.txt
# INFO: Processed SCB annotation: 0087_001053.txt
# INFO: Processed SCB annotation: 0104018.txt
# INFO: Processed SCB annotation: 1120003.txt
# INFO: Processed SCB annotation: 3001190.txt
# INFO: Processed SCB annotation: 138_002079.txt
# INFO: Processed SCB annotation: 1302006.txt
# INFO: Processed SCB annotation: 1276011.txt
# INFO: Processed SCB annotation: 1276040.txt
# INFO: Processed SCB annotation: 0089_000727.txt
# INFO: Processed SCB annotation: 3001353.txt
# INFO: Processed SCB annotation: 0016023.txt
# INFO: Processed SCB annotation: 3000206.txt
# INFO: Processed SCB annotation: 0202008.txt
# INFO: Processed SCB annotation: 1298013.txt
# INFO: Processed SCB annotation: 00030013.txt
# INFO: Processed SCB annotation: 15_001896.txt
# INFO: Processed SCB annotation: 1331017.txt
# INFO: Processed SCB annotation: 0090_001565.txt
# INFO: Processed SCB annotation: 18_001035.txt
# INFO: Processed SCB annotation: 0105011.txt
# INFO: Processed SCB annotation: 1257031.txt
# INFO: Processed SCB annotation: 134_000146.txt
# INFO: Processed SCB annotation: 18_001203.txt
# INFO: Processed SCB annotation: 1262013.txt
# INFO: Processed SCB annotation: 1265099.txt
# INFO: Processed SCB annotation: 0089_001620.txt
# INFO: Processed SCB annotation: 1312028.txt
# INFO: Processed SCB annotation: 10_001491.txt
# INFO: Processed SCB annotation: 11_000780.txt
# INFO: Processed SCB annotation: 18_001729.txt
# INFO: Processed SCB annotation: 1255001.txt
# INFO: Processed SCB annotation: 1281023.txt
# INFO: Processed SCB annotation: 1253075.txt
# INFO: Processed SCB annotation: 0401074.txt
# INFO: Processed SCB annotation: 0023018.txt
# INFO: Processed SCB annotation: 1332028.txt
# INFO: Processed SCB annotation: 0015012.txt
# INFO: Processed SCB annotation: 1254032.txt
# INFO: Processed SCB annotation: 0404038.txt
# INFO: Processed SCB annotation: 1265109.txt
# INFO: Processed SCB annotation: 1314012.txt
# INFO: Processed SCB annotation: 0088_001863.txt
# INFO: Processed SCB annotation: 0016002.txt
# INFO: Processed SCB annotation: 0016016.txt
# INFO: Processed SCB annotation: 3001114.txt
# INFO: Processed SCB annotation: 130_000365.txt
# INFO: Processed SCB annotation: 3002064.txt
# INFO: Processed SCB annotation: 11_000503.txt
# INFO: Processed SCB annotation: 1314033.txt
# INFO: Processed SCB annotation: 1302010.txt
# INFO: Processed SCB annotation: 0101017.txt
# INFO: Processed SCB annotation: 1270092.txt
# INFO: Processed SCB annotation: 1319005.txt
# INFO: Processed SCB annotation: 1266012.txt
# INFO: Processed SCB annotation: 1367001.txt
# INFO: Processed SCB annotation: 1265100.txt
# INFO: Processed SCB annotation: 13210051.txt
# INFO: Processed SCB annotation: 0105037.txt
# INFO: Processed SCB annotation: 0081_000453.txt
# INFO: Processed SCB annotation: 0012006.txt
# INFO: Processed SCB annotation: 0024012.txt
# INFO: Processed SCB annotation: 3000137.txt
# INFO: Processed SCB annotation: 0089_001807.txt
# INFO: Processed SCB annotation: 21_001016.txt
# INFO: Processed SCB annotation: 3002066.txt
# INFO: Processed SCB annotation: 1399006.txt
# INFO: Processed SCB annotation: 1281002.txt
# INFO: Processed SCB annotation: 3005019.txt
# INFO: Processed SCB annotation: 3005170.txt
# INFO: Processed SCB annotation: 0089_001638.txt
# INFO: Processed SCB annotation: 12_002228.txt
# INFO: Processed SCB annotation: 0001058.txt
# INFO: Processed SCB annotation: 0107025.txt
# INFO: Processed SCB annotation: 3005084.txt
# INFO: Processed SCB annotation: 1265093.txt
# INFO: Processed SCB annotation: 1297001.txt
# INFO: Processed SCB annotation: 2_000219.txt
# INFO: Processed SCB annotation: 130_000370.txt
# INFO: Processed SCB annotation: 3004194.txt
# INFO: Processed SCB annotation: 3005266.txt
# INFO: Processed SCB annotation: 1313012.txt
# INFO: Processed SCB annotation: 1281021.txt
# INFO: Processed SCB annotation: 57_000573.txt
# INFO: Processed SCB annotation: 60_001518.txt
# INFO: Processed SCB annotation: 0025008.txt
# INFO: Processed SCB annotation: 1433001.txt
# INFO: Processed SCB annotation: 0088_000443.txt
# INFO: Processed SCB annotation: 06010007.txt
# INFO: Processed SCB annotation: 0400022.txt
# INFO: Processed SCB annotation: 131_002270.txt
# INFO: Processed SCB annotation: 1292008.txt
# INFO: Processed SCB annotation: 18_002244.txt
# INFO: Processed SCB annotation: 57_000897.txt
# INFO: Processed SCB annotation: 0002055.txt
# INFO: Processed SCB annotation: 0203002.txt
# INFO: Processed SCB annotation: 3005259.txt
# INFO: Processed SCB annotation: 1265055.txt
# INFO: Processed SCB annotation: 0101061.txt
# INFO: Processed SCB annotation: 0401008.txt
# INFO: Processed SCB annotation: 11_000561.txt
# INFO: Processed SCB annotation: 0025060.txt
# INFO: Processed SCB annotation: 0400025.txt
# INFO: Processed SCB annotation: 1267069.txt
# INFO: Processed SCB annotation: 10_000262.txt
# INFO: Merge dataset thành công!

# %% [markdown]
# ### Tôi muốn đoạn code di chuyển data scb vào đường dẫn Student-Behavior-Recognition-6 ( Tương ứng với train, valid, test ). Và chuyển class_names = {0: 'hand-raising', 1: 'read', 2: 'write'}  thành 4 5 6 . Nhớ chuyển cả ảnh vào trong folder Student-Behavior-Recognition-6 ( Tương ứng với train, valid, test ).

# %% [markdown]
# #### Kiểm tra ảnh và label không khớp

# %%
import os
import glob

def check_image_label_match(images_dir, labels_dir):
    """
    Kiểm tra sự khớp nhau giữa ảnh và file label dựa theo tên file (không phần mở rộng).
    Trả về 2 tập hợp:
      - missing_labels: các ảnh không có file label tương ứng.
      - missing_images: các file label không có ảnh tương ứng.
    """
    # Lấy danh sách file ảnh (chấp nhận các định dạng ảnh khác nhau)
    image_files = glob.glob(os.path.join(images_dir, "*.*"))
    # Lấy danh sách file label với định dạng .txt
    label_files = glob.glob(os.path.join(labels_dir, "*.txt"))

    # Lấy tên file (không phần mở rộng)
    image_bases = {os.path.splitext(os.path.basename(f))[0] for f in image_files}
    label_bases = {os.path.splitext(os.path.basename(f))[0] for f in label_files}

    missing_labels = image_bases - label_bases
    missing_images = label_bases - image_bases

    return missing_labels, missing_images

def run_test_case():
    base_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6"
    splits = ["train", "valid", "test"]
    
    for split in splits:
        images_dir = os.path.join(base_dir, split, "images")
        labels_dir = os.path.join(base_dir, split, "labels")
        
        missing_labels, missing_images = check_image_label_match(images_dir, labels_dir)
        
        print(f"\nKiểm tra tập {split}:")
        if missing_labels or missing_images:
            if missing_labels:
                print(" - Ảnh không có file label tương ứng:", missing_labels)
            if missing_images:
                print(" - File label không có ảnh tương ứng:", missing_images)
        else:
            print(" - Tất cả ảnh và label đều khớp nhau.")
            
if __name__ == '__main__':
    run_test_case()
# Out:
# Kiểm tra tập train:
#  - Tất cả ảnh và label đều khớp nhau.
#
# Kiểm tra tập valid:
#  - Tất cả ảnh và label đều khớp nhau.
#
# Kiểm tra tập test:
#  - Tất cả ảnh và label đều khớp nhau.

# %% [markdown]
# ### Thực hiện merge data

# %%
import os
import glob
import shutil

# ===== Đường dẫn SCB (source) =====
# Train
src_train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train"
src_train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/train"
# Valid
src_val_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val"
src_val_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/val"
# Test
src_test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/test"
src_test_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/test"

# ===== Đường dẫn đích (Student-Behavior-Recognition-6) =====
# Train
dest_train_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/images"
dest_train_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels"
# Valid
dest_val_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/images"
dest_val_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels"
# Test
dest_test_images_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/images"
dest_test_labels_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels"

# ===== Mapping chuyển đổi class label =====
# Ban đầu: {0: 'hand-raising', 1: 'read', 2: 'write'}
# Sau khi chuyển: 0 -> 4, 1 -> 5, 2 -> 6
class_mapping = {0: 4, 1: 5, 2: 6}

def update_label_file(src_label_file, dest_label_file, class_mapping):
    """
    Đọc file label từ đường dẫn src_label_file, cập nhật class_id theo mapping,
    và ghi file mới tại dest_label_file.
    """
    with open(src_label_file, 'r') as f:
        lines = f.readlines()
    
    new_lines = []
    for line in lines:
        parts = line.strip().split()
        if not parts:
            continue
        try:
            cls = int(parts[0])
        except ValueError:
            continue
        if cls in class_mapping:
            new_cls = class_mapping[cls]
            new_line = " ".join([str(new_cls)] + parts[1:]) + "\n"
            new_lines.append(new_line)
        else:
            # Nếu không thuộc mapping (trường hợp bất thường) thì giữ nguyên dòng
            new_lines.append(line)
    
    with open(dest_label_file, 'w') as f:
        f.writelines(new_lines)

def process_dataset(src_images_dir, src_labels_dir, dest_images_dir, dest_labels_dir, class_mapping):
    """
    Copy ảnh và file label từ thư mục source sang thư mục destination,
    đồng thời cập nhật file label theo mapping class.
    """
    # Tạo thư mục đích nếu chưa tồn tại
    os.makedirs(dest_images_dir, exist_ok=True)
    os.makedirs(dest_labels_dir, exist_ok=True)

    # --- Copy ảnh ---
    image_files = glob.glob(os.path.join(src_images_dir, "*.*"))
    for img_file in image_files:
        shutil.copy(img_file, dest_images_dir)
    print(f"Đã copy {len(image_files)} ảnh từ {src_images_dir} sang {dest_images_dir}")

    # --- Cập nhật và copy file label ---
    label_files = glob.glob(os.path.join(src_labels_dir, "*.txt"))
    for label_file in label_files:
        dest_label_file = os.path.join(dest_labels_dir, os.path.basename(label_file))
        update_label_file(label_file, dest_label_file, class_mapping)
    print(f"Đã xử lý {len(label_files)} file label từ {src_labels_dir} sang {dest_labels_dir}")

# --- Xử lý cho train, valid và test ---
process_dataset(src_train_images_dir, src_train_labels_dir, dest_train_images_dir, dest_train_labels_dir, class_mapping)
process_dataset(src_val_images_dir, src_val_labels_dir, dest_val_images_dir, dest_val_labels_dir, class_mapping)
process_dataset(src_test_images_dir, src_test_labels_dir, dest_test_images_dir, dest_test_labels_dir, class_mapping)

print("Đã di chuyển dữ liệu SCB sang Student-Behavior-Recognition-6 và cập nhật class label thành 4, 5, 6!")
# Out:
# Đã copy 4674 ảnh từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/train sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/images
# Đã xử lý 4674 file label từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/train sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/train/labels
# Đã copy 1588 ảnh từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/val sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/images
# Đã xử lý 1588 file label từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/val sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/valid/labels
# Đã copy 602 ảnh từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/images/test sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/images
# Đã xử lý 602 file label từ /hdd2/minhnv/CodingYOLOv12/Dataset/SCB5-Handrise-Read-write-2024-9-17/labels/test sang /hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6/test/labels
# Đã di chuyển dữ liệu SCB sang Student-Behavior-Recognition-6 và cập nhật class label thành 4, 5, 6!

# %%
import os
import glob

def check_image_label_match(images_dir, labels_dir):
    """
    Kiểm tra sự khớp nhau giữa ảnh và file label dựa theo tên file (không phần mở rộng).
    Trả về 2 tập hợp:
      - missing_labels: các ảnh không có file label tương ứng.
      - missing_images: các file label không có ảnh tương ứng.
    """
    # Lấy danh sách file ảnh (chấp nhận các định dạng ảnh khác nhau)
    image_files = glob.glob(os.path.join(images_dir, "*.*"))
    # Lấy danh sách file label với định dạng .txt
    label_files = glob.glob(os.path.join(labels_dir, "*.txt"))

    # Lấy tên file (không phần mở rộng)
    image_bases = {os.path.splitext(os.path.basename(f))[0] for f in image_files}
    label_bases = {os.path.splitext(os.path.basename(f))[0] for f in label_files}

    missing_labels = image_bases - label_bases
    missing_images = label_bases - image_bases

    return missing_labels, missing_images

def run_test_case():
    base_dir = "/hdd2/minhnv/CodingYOLOv12/Dataset/Student-Behavior-Recognition-6"
    splits = ["train", "valid", "test"]
    
    for split in splits:
        images_dir = os.path.join(base_dir, split, "images")
        labels_dir = os.path.join(base_dir, split, "labels")
        
        missing_labels, missing_images = check_image_label_match(images_dir, labels_dir)
        
        print(f"\nKiểm tra tập {split}:")
        if missing_labels or missing_images:
            if missing_labels:
                print(" - Ảnh không có file label tương ứng:", missing_labels)
            if missing_images:
                print(" - File label không có ảnh tương ứng:", missing_images)
        else:
            print(" - Tất cả ảnh và label đều khớp nhau.")
            
if __name__ == '__main__':
    run_test_case()
# Out:
# Kiểm tra tập train:
#  - Tất cả ảnh và label đều khớp nhau.
#
# Kiểm tra tập valid:
#  - Tất cả ảnh và label đều khớp nhau.
#
# Kiểm tra tập test:
#  - Tất cả ảnh và label đều khớp nhau.
